# %%
import tensorflow as tf
from tensorflow.keras import layers

print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
model = tf.keras.Sequential()
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
layers.Dense(32, activation='sigmoid')
layers.Dense(32, activation=tf.sigmoid)
layers.Dense(32, kernel_initializer='orthogonal')
layers.Dense(32, kernel_initializer=tf.keras.initializers.glorot_normal)
layers.Dense(32, kernel_initializer=tf.keras.regularizers.l2(0.01))
layers.Dense(32, kernel_initializer=tf.keras.regularizers.l1(0.01))

# %%
model = tf.keras.Sequential()
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=[tf.keras.metrics.categorical_accuracy])

# %%
import numpy as np

train_x = np.random.random((1000, 72))
train_y = np.random.random((1000, 10))

val_x = np.random.random((200, 72))
val_y = np.random.random((200, 10))

model.fit(train_x, train_y, epochs=10, batch_size=100,
          validation_data=(val_x, val_y))
# Out:
# Epoch 1/10
# 10/10 [==============================] - 0s 19ms/step - loss: 11.7548 - categorical_accuracy: 0.0930 - val_loss: 11.6206 - val_categorical_accuracy: 0.0750
# Epoch 2/10
# 10/10 [==============================] - 0s 3ms/step - loss: 12.0237 - categorical_accuracy: 0.0990 - val_loss: 12.2593 - val_categorical_accuracy: 0.0900
# Epoch 3/10
# 10/10 [==============================] - 0s 3ms/step - loss: 13.0089 - categorical_accuracy: 0.0900 - val_loss: 13.7678 - val_categorical_accuracy: 0.0950
# Epoch 4/10
# 10/10 [==============================] - 0s 3ms/step - loss: 15.0365 - categorical_accuracy: 0.0920 - val_loss: 16.4185 - val_categorical_accuracy: 0.0950
# Epoch 5/10
# 10/10 [==============================] - 0s 3ms/step - loss: 18.0272 - categorical_accuracy: 0.0920 - val_loss: 19.4658 - val_categorical_accuracy: 0.0950
# Epoch 6/10
# 10/10 [==============================] - 0s 3ms/step - loss: 20.8010 - categorical_accuracy: 0.0920 - val_loss: 22.0212 - val_categorical_accuracy: 0.0950
# Epoch 7/10
# 10/10 [==============================] - 0s 4ms/step - loss: 23.9676 - categorical_accuracy: 0.0920 - val_loss: 26.4783 - val_categorical_accuracy: 0.0900
# Epoch 8/10
# 10/10 [==============================] - 0s 3ms/step - loss: 29.5379 - categorical_accuracy: 0.0920 - val_loss: 33.1644 - val_categorical_accuracy: 0.0900
# Epoch 9/10
# 10/10 [==============================] - 0s 3ms/step - loss: 36.8427 - categorical_accuracy: 0.0950 - val_loss: 40.9792 - val_categorical_accuracy: 0.0750
# Epoch 10/10
# 10/10 [==============================] - 0s 3ms/step - loss: 45.0152 - categorical_accuracy: 0.0950 - val_loss: 49.5434 - val_categorical_accuracy: 0.0700

# %%
dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y))
dataset = dataset.batch(32)
dataset = dataset.repeat()
val_dataset = tf.data.Dataset.from_tensor_slices((val_x, val_y))
val_dataset = val_dataset.batch(32)
val_dataset = val_dataset.repeat()

model.fit(dataset, epochs=10, steps_per_epoch=30,
          validation_data=val_dataset, validation_steps=3)
# Out:
# Epoch 1/10
# WARNING:tensorflow:Layer dense_9 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 30/30 [==============================] - 0s 6ms/step - loss: 63.9175 - categorical_accuracy: 0.0854 - val_loss: 78.5873 - val_categorical_accuracy: 0.0938
# Epoch 2/10
# 30/30 [==============================] - 0s 2ms/step - loss: 95.0536 - categorical_accuracy: 0.0919 - val_loss: 110.4719 - val_categorical_accuracy: 0.0833
# Epoch 3/10
# 30/30 [==============================] - 0s 2ms/step - loss: 126.4452 - categorical_accuracy: 0.0940 - val_loss: 140.1442 - val_categorical_accuracy: 0.1042
# Epoch 4/10
# 30/30 [==============================] - 0s 3ms/step - loss: 154.0171 - categorical_accuracy: 0.1015 - val_loss: 164.7512 - val_categorical_accuracy: 0.1042
# Epoch 5/10
# 30/30 [==============================] - 0s 2ms/step - loss: 178.9891 - categorical_accuracy: 0.1143 - val_loss: 193.1586 - val_categorical_accuracy: 0.0729
# Epoch 6/10
# 30/30 [==============================] - 0s 2ms/step - loss: 212.5887 - categorical_accuracy: 0.1015 - val_loss: 228.7809 - val_categorical_accuracy: 0.0521
# Epoch 7/10
# 30/30 [==============================] - 0s 2ms/step - loss: 249.5101 - categorical_accuracy: 0.1047 - val_loss: 264.6369 - val_categorical_accuracy: 0.1458
# Epoch 8/10
# 30/30 [==============================] - 0s 2ms/step - loss: 283.4942 - categorical_accuracy: 0.0897 - val_loss: 293.5218 - val_categorical_accuracy: 0.1042
# Epoch 9/10
# 30/30 [==============================] - 0s 3ms/step - loss: 306.7231 - categorical_accuracy: 0.0919 - val_loss: 312.9194 - val_categorical_accuracy: 0.0417
# Epoch 10/10
# 30/30 [==============================] - 0s 2ms/step - loss: 320.1527 - categorical_accuracy: 0.0865 - val_loss: 314.4596 - val_categorical_accuracy: 0.1042

# %%
test_x = np.random.random((1000, 72))
test_y = np.random.random((1000, 10))
model.evaluate(test_x, test_y, batch_size=32)
test_data = tf.data.Dataset.from_tensor_slices((test_x, test_y))
test_data = test_data.batch(32).repeat()
model.evaluate(test_data, steps=30)
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 318.0471 - categorical_accuracy: 0.1040
# 30/30 [==============================] - 0s 1ms/step - loss: 318.1983 - categorical_accuracy: 0.1052
# [318.19830322265625, 0.10520832985639572]

# %%
result = model.predict(test_x, batch_size=32)
print(result)
# Out:
# [[1.8939565e-01 4.3395451e-01 1.0464529e-01 ... 0.0000000e+00
#   8.4951483e-02 3.6638343e-26]
#  [1.3164739e-01 4.1188824e-01 1.0734259e-01 ... 0.0000000e+00
#   1.3463777e-01 6.0348541e-23]
#  [2.0022528e-01 4.5809650e-01 7.8677803e-02 ... 0.0000000e+00
#   1.0790801e-01 5.3602579e-28]
#  ...
#  [1.1454364e-01 4.5680499e-01 8.0709651e-02 ... 0.0000000e+00
#   1.1561123e-01 1.9823833e-26]
#  [1.4888187e-01 4.1127676e-01 1.4082092e-01 ... 0.0000000e+00
#   1.2623106e-01 2.0522938e-26]
#  [1.0472209e-01 4.5489201e-01 1.1131291e-01 ... 0.0000000e+00
#   1.0451775e-01 8.1317808e-25]]

# %%
input_x = tf.keras.Input(shape=(72,))
hidden1 = layers.Dense(32, activation='relu')(input_x)
hidden2 = layers.Dense(16, activation='relu')(hidden1)
pred = layers.Dense(10, activation='softmax')(hidden2)

model = tf.keras.Model(inputs=input_x, outputs=pred)
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
             loss=tf.keras.losses.categorical_crossentropy,
             metrics=['accuracy'])
model.fit(train_x, train_y, batch_size=32, epochs=5)
# Out:
# Epoch 1/5
# 32/32 [==============================] - 0s 2ms/step - loss: 13.6314 - accuracy: 0.1120
# Epoch 2/5
# 32/32 [==============================] - 0s 1ms/step - loss: 22.3355 - accuracy: 0.1110
# Epoch 3/5
# 32/32 [==============================] - 0s 1ms/step - loss: 38.5410 - accuracy: 0.0870
# Epoch 4/5
# 32/32 [==============================] - 0s 2ms/step - loss: 65.7872 - accuracy: 0.0840
# Epoch 5/5
# 32/32 [==============================] - 0s 2ms/step - loss: 108.2964 - accuracy: 0.0860

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=2, monitor='val_loss'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs')
]
model.fit(train_x, train_y, batch_size=16, epochs=5,
         callbacks=callbacks, validation_data=(val_x, val_y))
# Out:
# Epoch 1/5
#  1/63 [..............................] - ETA: 0s - loss: 10.7923 - accuracy: 0.1250WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0048s vs `on_train_batch_end` time: 0.0284s). Check your callbacks.
# 63/63 [==============================] - 0s 4ms/step - loss: 11.4875 - accuracy: 0.1030 - val_loss: 11.3425 - val_accuracy: 0.0650
# Epoch 2/5
# 63/63 [==============================] - 0s 1ms/step - loss: 11.4863 - accuracy: 0.0960 - val_loss: 11.3442 - val_accuracy: 0.0600
# Epoch 3/5
# 63/63 [==============================] - 0s 1ms/step - loss: 11.4866 - accuracy: 0.0910 - val_loss: 11.3437 - val_accuracy: 0.0650

# %%
strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    model = tf.keras.Sequential()
    model.add(layers.Dense(16, activation='relu', input_shape=(10,)))
    model.add(layers.Dense(1, activation='sigmoid'))
    optimizer = tf.keras.optimizers.SGD(0.2)
    model.compile(loss='binary_crossentropy', optimizer=optimizer)
model.summary()
# Out:
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 16)                176
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
x = np.random.random((1024, 10))
y = np.random.randint(2, size=(1024, 1))
x = tf.cast(x, tf.float32)
dataset = tf.data.Dataset.from_tensor_slices((x, y))
dataset = dataset.shuffle(buffer_size=1024).batch(32)
model.fit(dataset, epochs=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6964
