# %%
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers
print(tf.__version__)
# Out:
# 2.3.0

# %%
#1.回归任务
(x_train, y_train), (x_test, y_test) = keras.datasets.boston_housing.load_data()
print(x_train.shape, ' ', y_train.shape)
print(x_test.shape, ' ', y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step
# (404, 13)   (404,)
# (102, 13)   (102,)

# %%
model = keras.Sequential([
    layers.Dense(32, activation='sigmoid', input_shape=(13,)),
    layers.Dense(32, activation='sigmoid'),
    layers.Dense(32, activation='sigmoid'),
    layers.Dense(1)
])

model.compile(optimizer=keras.optimizers.SGD(0.1),
             loss='mean_squared_error',  # keras.losses.mean_squared_error
             metrics=['mse'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                448
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 2,593
# Trainable params: 2,593
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, batch_size=50, epochs=50, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 0s 22ms/step - loss: 270.5546 - mse: 270.5546 - val_loss: 49.9185 - val_mse: 49.9185
# Epoch 2/50
# 8/8 [==============================] - 0s 4ms/step - loss: 90.7461 - mse: 90.7461 - val_loss: 42.5429 - val_mse: 42.5429
# Epoch 3/50
# 8/8 [==============================] - 0s 3ms/step - loss: 90.4364 - mse: 90.4364 - val_loss: 44.1750 - val_mse: 44.1750
# Epoch 4/50
# 8/8 [==============================] - 0s 3ms/step - loss: 90.4192 - mse: 90.4192 - val_loss: 44.5169 - val_mse: 44.5169
# Epoch 5/50
# 8/8 [==============================] - 0s 3ms/step - loss: 90.4189 - mse: 90.4189 - val_loss: 44.6126 - val_mse: 44.6126
# Epoch 6/50
# 8/8 [==============================] - 0s 3ms/step - loss: 93.7302 - mse: 93.7302 - val_loss: 63.5683 - val_mse: 63.5683
# Epoch 7/50
# 8/8 [==============================] - 0s 5ms/step - loss: 92.3101 - mse: 92.3101 - val_loss: 43.3487 - val_mse: 43.3487
# Epoch 8/50
# 8/8 [==============================] - 0s 3ms/step - loss: 90.5287 - mse: 90.5287 - val_loss: 52.9795 - val_mse: 52.9795
# Epoch 9/50
# 8/8 [==============================] - 0s 3ms/step - loss: 91.9770 - mse: 91.9770 - val_loss: 42.4348 - val_mse: 42.4348
# Epoch 10/50
# 8/8 [==============================] - 0s 3ms/step - loss: 89.1734 - mse: 89.1734 - val_loss: 42.3227 - val_mse: 42.3227
# Epoch 11/50
# 8/8 [==============================] - 0s 3ms/step - loss: 88.7281 - mse: 88.7281 - val_loss: 42.7241 - val_mse: 42.7241
# Epoch 12/50
# 8/8 [==============================] - 0s 3ms/step - loss: 87.7711 - mse: 87.7711 - val_loss: 86.9214 - val_mse: 86.9214
# Epoch 13/50
# 8/8 [==============================] - 0s 3ms/step - loss: 100.5636 - mse: 100.5636 - val_loss: 48.9473 - val_mse: 48.9473
# Epoch 14/50
# 8/8 [==============================] - 0s 4ms/step - loss: 92.7959 - mse: 92.7959 - val_loss: 53.6904 - val_mse: 53.6904
# Epoch 15/50
# 8/8 [==============================] - 0s 4ms/step - loss: 90.0813 - mse: 90.0813 - val_loss: 48.4370 - val_mse: 48.4370
# Epoch 16/50
# 8/8 [==============================] - 0s 3ms/step - loss: 90.0375 - mse: 90.0375 - val_loss: 44.7596 - val_mse: 44.7596
# Epoch 17/50
# 8/8 [==============================] - 0s 3ms/step - loss: 91.0345 - mse: 91.0345 - val_loss: 42.5844 - val_mse: 42.5844
# Epoch 18/50
# 8/8 [==============================] - 0s 3ms/step - loss: 89.8530 - mse: 89.8530 - val_loss: 42.7089 - val_mse: 42.7089
# Epoch 19/50
# 8/8 [==============================] - 0s 4ms/step - loss: 90.6079 - mse: 90.6079 - val_loss: 44.9824 - val_mse: 44.9824
# Epoch 20/50
# 8/8 [==============================] - 0s 3ms/step - loss: 90.4916 - mse: 90.4916 - val_loss: 44.5567 - val_mse: 44.5567
# Epoch 21/50
# 8/8 [==============================] - 0s 3ms/step - loss: 90.5288 - mse: 90.5288 - val_loss: 42.9432 - val_mse: 42.9432
# Epoch 22/50
# 8/8 [==============================] - 0s 3ms/step - loss: 88.5099 - mse: 88.5099 - val_loss: 42.9252 - val_mse: 42.9252
# Epoch 23/50
# 8/8 [==============================] - 0s 3ms/step - loss: 90.1049 - mse: 90.1049 - val_loss: 47.1077 - val_mse: 47.1077
# Epoch 24/50
# 8/8 [==============================] - 0s 4ms/step - loss: 89.0781 - mse: 89.0781 - val_loss: 43.4703 - val_mse: 43.4703
# Epoch 25/50
# 8/8 [==============================] - 0s 3ms/step - loss: 89.7242 - mse: 89.7242 - val_loss: 177.6514 - val_mse: 177.6514
# Epoch 26/50
# 8/8 [==============================] - 0s 3ms/step - loss: 104.4625 - mse: 104.4625 - val_loss: 43.5867 - val_mse: 43.5867
# Epoch 27/50
# 8/8 [==============================] - 0s 4ms/step - loss: 91.6295 - mse: 91.6295 - val_loss: 43.1997 - val_mse: 43.1997
# Epoch 28/50
# 8/8 [==============================] - 0s 4ms/step - loss: 89.7446 - mse: 89.7446 - val_loss: 44.1999 - val_mse: 44.1999
# Epoch 29/50
# 8/8 [==============================] - 0s 4ms/step - loss: 90.8128 - mse: 90.8128 - val_loss: 43.2836 - val_mse: 43.2836
# Epoch 30/50
# 8/8 [==============================] - 0s 4ms/step - loss: 90.0781 - mse: 90.0781 - val_loss: 43.1475 - val_mse: 43.1475
# Epoch 31/50
# 8/8 [==============================] - 0s 3ms/step - loss: 91.1757 - mse: 91.1757 - val_loss: 58.7030 - val_mse: 58.7030
# Epoch 32/50
# 8/8 [==============================] - 0s 3ms/step - loss: 91.7992 - mse: 91.7992 - val_loss: 49.2827 - val_mse: 49.2827
# Epoch 33/50
# 8/8 [==============================] - 0s 3ms/step - loss: 91.0552 - mse: 91.0552 - val_loss: 46.6758 - val_mse: 46.6758
# Epoch 34/50
# 8/8 [==============================] - 0s 3ms/step - loss: 89.6928 - mse: 89.6928 - val_loss: 51.2950 - val_mse: 51.2950
# Epoch 35/50
# 8/8 [==============================] - 0s 3ms/step - loss: 89.2095 - mse: 89.2095 - val_loss: 55.7483 - val_mse: 55.7483
# Epoch 36/50
# 8/8 [==============================] - 0s 3ms/step - loss: 92.8710 - mse: 92.8710 - val_loss: 46.6826 - val_mse: 46.6826
# Epoch 37/50
# 8/8 [==============================] - 0s 3ms/step - loss: 91.2517 - mse: 91.2517 - val_loss: 45.9776 - val_mse: 45.9776
# Epoch 38/50
# 8/8 [==============================] - 0s 4ms/step - loss: 90.3426 - mse: 90.3426 - val_loss: 42.6712 - val_mse: 42.6712
# Epoch 39/50
# 8/8 [==============================] - 0s 4ms/step - loss: 92.6087 - mse: 92.6087 - val_loss: 42.6925 - val_mse: 42.6925
# Epoch 40/50
# 8/8 [==============================] - 0s 4ms/step - loss: 91.0860 - mse: 91.0860 - val_loss: 42.7406 - val_mse: 42.7406
# Epoch 41/50
# 8/8 [==============================] - 0s 3ms/step - loss: 90.1069 - mse: 90.1069 - val_loss: 53.0001 - val_mse: 53.0001
# Epoch 42/50
# 8/8 [==============================] - 0s 4ms/step - loss: 92.3425 - mse: 92.3425 - val_loss: 42.8258 - val_mse: 42.8258
# Epoch 43/50
# 8/8 [==============================] - 0s 4ms/step - loss: 90.3542 - mse: 90.3542 - val_loss: 44.2521 - val_mse: 44.2521
# Epoch 44/50
# 8/8 [==============================] - 0s 4ms/step - loss: 91.3979 - mse: 91.3979 - val_loss: 43.9125 - val_mse: 43.9125
# Epoch 45/50
# 8/8 [==============================] - 0s 4ms/step - loss: 90.4471 - mse: 90.4471 - val_loss: 55.8494 - val_mse: 55.8494
# Epoch 46/50
# 8/8 [==============================] - 0s 4ms/step - loss: 89.3267 - mse: 89.3267 - val_loss: 42.8398 - val_mse: 42.8398
# Epoch 47/50
# 8/8 [==============================] - 0s 4ms/step - loss: 90.7545 - mse: 90.7545 - val_loss: 42.7746 - val_mse: 42.7746
# Epoch 48/50
# 8/8 [==============================] - 0s 3ms/step - loss: 90.0313 - mse: 90.0313 - val_loss: 43.5591 - val_mse: 43.5591
# Epoch 49/50
# 8/8 [==============================] - 0s 4ms/step - loss: 91.8395 - mse: 91.8395 - val_loss: 69.4273 - val_mse: 69.4273
# Epoch 50/50
# 8/8 [==============================] - 0s 3ms/step - loss: 90.7423 - mse: 90.7423 - val_loss: 42.8424 - val_mse: 42.8424

# %%
#2.分类任务

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

whole_data = load_breast_cancer()
x_data = whole_data.data
y_data = whole_data.target

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.3, random_state=7)

print(x_train.shape, ' ', y_train.shape)
print(x_test.shape, ' ', y_test.shape)
# Out:
# (398, 30)   (398,)
# (171, 30)   (171,)

# %%
model = keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(30,)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=keras.optimizers.Adam(),
             loss=keras.losses.binary_crossentropy,
             metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 32)                992
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 2,081
# Trainable params: 2,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, batch_size=64, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 50.8440 - accuracy: 0.3945
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 9.8015 - accuracy: 0.5377
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 11.9488 - accuracy: 0.6508
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 3.6906 - accuracy: 0.5653
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4365 - accuracy: 0.6734
# Epoch 6/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0178 - accuracy: 0.8543
# Epoch 7/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7025 - accuracy: 0.7136
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2075 - accuracy: 0.8442
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1591 - accuracy: 0.8643
# Epoch 10/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0929 - accuracy: 0.7940

# %%
model.evaluate(x_test, y_test)
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7196 - accuracy: 0.9064
# [0.7195661067962646, 0.9064327478408813]

# %%
print(model.metrics_names)
# Out:
# ['loss', 'accuracy']
