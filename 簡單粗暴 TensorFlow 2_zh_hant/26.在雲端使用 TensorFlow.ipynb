# %% [markdown]
# **在 Colab 中使用 TensorFlow**
#
# Google Colab 是谷歌的免費線上互動式 Python 運行環境，且提供 GPU 支持，使得機器學習開發者們無需在自己的電腦上安裝環境，就能隨時隨地從雲端使用和運行自己的機器學習程式碼
#
# 剩下請參考網頁: https://tf.wiki/zh_hant/appendix/cloud.html
