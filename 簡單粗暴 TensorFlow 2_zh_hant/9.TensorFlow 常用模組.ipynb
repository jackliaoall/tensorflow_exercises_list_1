# %% [markdown]
# **tf.train.Checkpoint ：變數的保存與還原**
#
# 很多時候，我們希望在模型訓練完成後能將訓練好的參數（變數）保存起來。在需要使用模型的其他地方載入模型和參數，就能直接得到訓練好的模型。可能你第一個想到的是用 Python 的序列化模組 pickle 存儲 model.variables。但不幸的是，TensorFlow 的變數類型 ResourceVariable 並不能被序列化。
#
# 最後提供一個實例，以前章的 多層感知器模型 為例展示模型變數的保存和載入：

# %%
import tensorflow as tf
import numpy as np

class MNISTLoader():
    def __init__(self):
        mnist = tf.keras.datasets.mnist
        (self.train_data, self.train_label), (self.test_data, self.test_label) = mnist.load_data()
        # MNIST中的圖片預設為uint8（0-255的數字）。以下程式碼將其正規化到0-1之間的浮點數，並在最後增加一維作為顏色通道
        self.train_data = np.expand_dims(self.train_data.astype(np.float32) / 255.0, axis=-1)      # [60000, 28, 28, 1]
        self.test_data = np.expand_dims(self.test_data.astype(np.float32) / 255.0, axis=-1)        # [10000, 28, 28, 1]
        self.train_label = self.train_label.astype(np.int32)    # [60000]
        self.test_label = self.test_label.astype(np.int32)      # [10000]
        self.num_train_data, self.num_test_data = self.train_data.shape[0], self.test_data.shape[0]

    def get_batch(self, batch_size):
        # 從資料集中隨機取出batch_size個元素並返回
        index = np.random.randint(0, self.num_train_data, batch_size)
        return self.train_data[index, :], self.train_label[index]

class MLP(tf.keras.Model):
  def __init__(self):
      super().__init__()
      self.flatten = tf.keras.layers.Flatten()    # Flatten層將除第一維（batch_size）以外的維度展平
      self.dense1 = tf.keras.layers.Dense(units=100, activation=tf.nn.relu)
      self.dense2 = tf.keras.layers.Dense(units=10)

  def call(self, inputs):         # [batch_size, 28, 28, 1]
      x = self.flatten(inputs)    # [batch_size, 784]
      x = self.dense1(x)          # [batch_size, 100]
      x = self.dense2(x)          # [batch_size, 10]
      output = tf.nn.softmax(x)
      return output

num_epochs = 5
batch_size = 50
learning_rate = 0.001

model = MLP()
data_loader = MNISTLoader()
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # train.py 模型訓練階段
# model = MyModel()
# # 實例化Checkpoint，指定保存對象為model（如果需要保存Optimizer的參數也可加入）
# checkpoint = tf.train.Checkpoint(myModel=model)
# # ...（模型訓練程式碼）
# # 模型訓練完畢後將參數保存到文件（也可以在模型訓練過程中每隔一段時間就保存一次）
# checkpoint.save('./save/model.ckpt')

# %%
#跑到一半按停止
checkpoint = tf.train.Checkpoint(myAwesomeModel=model)      
# 使用tf.train.CheckpointManager管理Checkpoint
manager = tf.train.CheckpointManager(checkpoint, directory='./save', max_to_keep=3)

num_batches = int(data_loader.num_train_data // batch_size * num_epochs)

for batch_index in range(num_batches):
    X, y = data_loader.get_batch(batch_size)
    with tf.GradientTape() as tape:
        y_pred = model(X)
        loss = tf.keras.losses.sparse_categorical_crossentropy(y_true=y, y_pred=y_pred)
        loss = tf.reduce_mean(loss)
        print("batch %d: loss %f" % (batch_index, loss.numpy()))
    grads = tape.gradient(loss, model.variables)
    optimizer.apply_gradients(grads_and_vars=zip(grads, model.variables))

    path = manager.save(checkpoint_number=batch_index)         
    print("model saved to %s" % path)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# batch 1094: loss 0.196923
# model saved to ./save/ckpt-1094
# batch 1095: loss 0.140449
# model saved to ./save/ckpt-1095
# batch 1096: loss 0.064256
# model saved to ./save/ckpt-1096
# batch 1097: loss 0.252140
# model saved to ./save/ckpt-1097
# batch 1098: loss 0.058045
# model saved to ./save/ckpt-1098
# batch 1099: loss 0.095853
# model saved to ./save/ckpt-1099
# batch 1100: loss 0.147519
# model saved to ./save/ckpt-1100
# batch 1101: loss 0.239354
# model saved to ./save/ckpt-1101
# batch 1102: loss 0.111969
# model saved to ./save/ckpt-1102
# batch 1103: loss 0.315267
# model saved to ./save/ckpt-1103
# batch 1104: loss 0.181788
# model saved to ./save/ckpt-1104
# batch 1105: loss 0.207790
# model saved to ./save/ckpt-1105
# batch 1106: loss 0.138629
# model saved to ./save/ckpt-1106
# batch 1107: loss 0.253511
# model saved to ./save/ckpt-1107
# batch 1108: loss 0.265074
# model saved to ./save/ckpt-1108
# batch 1109: loss 0.085185
# model saved to ./save/ckpt-1109
# batch 1110: loss 0.362376
# model saved to ./save/ckpt-1110
# batch 1111: loss 0.307552
# model saved to ./save/ckpt-1111
# batch 1112: loss 0.266483
# model saved to ./save/ckpt-1112
# batch 1113: loss 0.173649
# model saved to ./save/ckpt-1113
# batch 1114: loss 0.198334
# model saved to ./save/ckpt-1114
# batch 1115: loss 0.068428
# model saved to ./save/ckpt-1115
# batch 1116: loss 0.113712
# model saved to ./save/ckpt-1116
# batch 1117: loss 0.211523
# model saved to ./save/ckpt-1117
# batch 1118: loss 0.279546
# model saved to ./save/ckpt-1118
# batch 1119: loss 0.128124
# model saved to ./save/ckpt-1119
# batch 1120: loss 0.097099
# model saved to ./save/ckpt-1120
# batch 1121: loss 0.130892
# model saved to ./save/ckpt-1121
# batch 1122: loss 0.189140
# model saved to ./save/ckpt-1122
# batch 1123: loss 0.226225
# model saved to ./save/ckpt-1123
# batch 1124: loss 0.092812
# model saved to ./save/ckpt-1124
# batch 1125: loss 0.087362
# model saved to ./save/ckpt-1125
# batch 1126: loss 0.180341
# model saved to ./save/ckpt-1126
# batch 1127: loss 0.164869
# model saved to ./save/ckpt-1127
# batch 1128: loss 0.437334
# model saved to ./save/ckpt-1128
# batch 1129: loss 0.140635
# model saved to ./save/ckpt-1129
# batch 1130: loss 0.083238
# model saved to ./save/ckpt-1130
# batch 1131: loss 0.060115
# model saved to ./save/ckpt-1131
# batch 1132: loss 0.056116
# model saved to ./save/ckpt-1132
# batch 1133: loss 0.062088
# model saved to ./save/ckpt-1133
# batch 1134: loss 0.212470
# model saved to ./save/ckpt-1134
# batch 1135: loss 0.181451
# model saved to ./save/ckpt-1135
# batch 1136: loss 0.267627
# model saved to ./save/ckpt-1136
# batch 1137: loss 0.255137
# model saved to ./save/ckpt-1137
# batch 1138: loss 0.269641
# model saved to ./save/ckpt-1138
# batch 1139: loss 0.110282
# model saved to ./save/ckpt-1139
# batch 1140: loss 0.123704
# model saved to ./save/ckpt-1140
# batch 1141: loss 0.150629
# model saved to ./save/ckpt-1141
# batch 1142: loss 0.308681
# model saved to ./save/ckpt-1142
# batch 1143: loss 0.068498
# model saved to ./save/ckpt-1143
# batch 1144: loss 0.150106
# model saved to ./save/ckpt-1144
# batch 1145: loss 0.331025
# model saved to ./save/ckpt-1145
# batch 1146: loss 0.209053
# model saved to ./save/ckpt-1146
# batch 1147: loss 0.157140
# model saved to ./save/ckpt-1147
# batch 1148: loss 0.157379
# model saved to ./save/ckpt-1148
# batch 1149: loss 0.134607
# model saved to ./save/ckpt-1149
# batch 1150: loss 0.163427
# model saved to ./save/ckpt-1150
# batch 1151: loss 0.239701
# model saved to ./save/ckpt-1151
# batch 1152: loss 0.178049
# model saved to ./save/ckpt-1152
# batch 1153: loss 0.157106
# model saved to ./save/ckpt-1153
# batch 1154: loss 0.094735
# model saved to ./save/ckpt-1154
# batch 1155: loss 0.101570
# model saved to ./save/ckpt-1155
# batch 1156: loss 0.141401
# model saved to ./save/ckpt-1156
# batch 1157: loss 0.119811
# model saved to ./save/ckpt-1157
# batch 1158: loss 0.192775
# model saved to ./save/ckpt-1158
# batch 1159: loss 0.126464
# model saved to ./save/ckpt-1159
# batch 1160: loss 0.197698
# model saved to ./save/ckpt-1160
# batch 1161: loss 0.125925
# model saved to ./save/ckpt-1161
# batch 1162: loss 0.044200
# model saved to ./save/ckpt-1162
# batch 1163: loss 0.032142
# model saved to ./save/ckpt-1163
# batch 1164: loss 0.116155
# model saved to ./save/ckpt-1164
# batch 1165: loss 0.294134
# model saved to ./save/ckpt-1165
# batch 1166: loss 0.050898
# model saved to ./save/ckpt-1166
# batch 1167: loss 0.166410
# model saved to ./save/ckpt-1167
# batch 1168: loss 0.257089
# model saved to ./save/ckpt-1168
# batch 1169: loss 0.332963
# model saved to ./save/ckpt-1169
# batch 1170: loss 0.313004
# model saved to ./save/ckpt-1170
# batch 1171: loss 0.153387
# model saved to ./save/ckpt-1171
# batch 1172: loss 0.160296
# model saved to ./save/ckpt-1172
# batch 1173: loss 0.045546
# model saved to ./save/ckpt-1173
# batch 1174: loss 0.292748
# model saved to ./save/ckpt-1174
# batch 1175: loss 0.114178
# model saved to ./save/ckpt-1175
# batch 1176: loss 0.180281
# model saved to ./save/ckpt-1176
# batch 1177: loss 0.206291
# model saved to ./save/ckpt-1177
# batch 1178: loss 0.067815
# model saved to ./save/ckpt-1178
# batch 1179: loss 0.068069
# model saved to ./save/ckpt-1179
# batch 1180: loss 0.168892
# model saved to ./save/ckpt-1180
# batch 1181: loss 0.176910
# model saved to ./save/ckpt-1181
# batch 1182: loss 0.124411
# model saved to ./save/ckpt-1182
# batch 1183: loss 0.170043
# model saved to ./save/ckpt-1183
# batch 1184: loss 0.081250
# model saved to ./save/ckpt-1184
# batch 1185: loss 0.193201
# model saved to ./save/ckpt-1185
# batch 1186: loss 0.229847
# model saved to ./save/ckpt-1186
# batch 1187: loss 0.076291
# model saved to ./save/ckpt-1187
# batch 1188: loss 0.078785
# model saved to ./save/ckpt-1188
# batch 1189: loss 0.275500
# model saved to ./save/ckpt-1189
# batch 1190: loss 0.246525
# model saved to ./save/ckpt-1190
# batch 1191: loss 0.092376
# model saved to ./save/ckpt-1191
# batch 1192: loss 0.066477
# model saved to ./save/ckpt-1192
# batch 1193: loss 0.066280
# model saved to ./save/ckpt-1193
# batch 1194: loss 0.239200
# model saved to ./save/ckpt-1194
# batch 1195: loss 0.186632
# model saved to ./save/ckpt-1195
# batch 1196: loss 0.151251
# model saved to ./save/ckpt-1196
# batch 1197: loss 0.164192
# model saved to ./save/ckpt-1197
# batch 1198: loss 0.110040
# model saved to ./save/ckpt-1198
# batch 1199: loss 0.224423
# model saved to ./save/ckpt-1199
# batch 1200: loss 0.278410
# model saved to ./save/ckpt-1200
# batch 1201: loss 0.106917
# model saved to ./save/ckpt-1201
# batch 1202: loss 0.141181
# model saved to ./save/ckpt-1202
# batch 1203: loss 0.260142
# model saved to ./save/ckpt-1203
# batch 1204: loss 0.396925
# model saved to ./save/ckpt-1204
# batch 1205: loss 0.145093
# model saved to ./save/ckpt-1205
# batch 1206: loss 0.173138
# model saved to ./save/ckpt-1206
# batch 1207: loss 0.167635
# model saved to ./save/ckpt-1207
# batch 1208: loss 0.178349
# model saved to ./save/ckpt-1208
# batch 1209: loss 0.026185
# model saved to ./save/ckpt-1209
# batch 1210: loss 0.148019
# model saved to ./save/ckpt-1210
# batch 1211: loss 0.162779
# model saved to ./save/ckpt-1211
# batch 1212: loss 0.155590
# model saved to ./save/ckpt-1212
# batch 1213: loss 0.191230
# model saved to ./save/ckpt-1213
# batch 1214: loss 0.198841
# model saved to ./save/ckpt-1214
# batch 1215: loss 0.094953
# model saved to ./save/ckpt-1215
# batch 1216: loss 0.124712
# model saved to ./save/ckpt-1216
# batch 1217: loss 0.117784
# model saved to ./save/ckpt-1217
# batch 1218: loss 0.138890
# model saved to ./save/ckpt-1218
# batch 1219: loss 0.101388
# model saved to ./save/ckpt-1219
# batch 1220: loss 0.136076
# model saved to ./save/ckpt-1220
# batch 1221: loss 0.201566
# model saved to ./save/ckpt-1221
# batch 1222: loss 0.074049
# model saved to ./save/ckpt-1222
# batch 1223: loss 0.145682
# model saved to ./save/ckpt-1223
# batch 1224: loss 0.099879
# model saved to ./save/ckpt-1224
# batch 1225: loss 0.180630
# model saved to ./save/ckpt-1225
# batch 1226: loss 0.170752
# model saved to ./save/ckpt-1226
# batch 1227: loss 0.333117
# model saved to ./save/ckpt-1227
# batch 1228: loss 0.150026
# model saved to ./save/ckpt-1228
# batch 1229: loss 0.113731
# model saved to ./save/ckpt-1229
# batch 1230: loss 0.216762
# model saved to ./save/ckpt-1230
# batch 1231: loss 0.100070
# model saved to ./save/ckpt-1231
# batch 1232: loss 0.225146
# model saved to ./save/ckpt-1232
# batch 1233: loss 0.110552
# model saved to ./save/ckpt-1233
# batch 1234: loss 0.239082
# model saved to ./save/ckpt-1234
# batch 1235: loss 0.170904
# model saved to ./save/ckpt-1235
# batch 1236: loss 0.451333
# model saved to ./save/ckpt-1236
# batch 1237: loss 0.046857
# model saved to ./save/ckpt-1237
# batch 1238: loss 0.110595
# model saved to ./save/ckpt-1238
# batch 1239: loss 0.069041
# model saved to ./save/ckpt-1239
# batch 1240: loss 0.074469
# model saved to ./save/ckpt-1240
# batch 1241: loss 0.252921
# model saved to ./save/ckpt-1241
# batch 1242: loss 0.097403
# model saved to ./save/ckpt-1242
# batch 1243: loss 0.097742
# model saved to ./save/ckpt-1243
# batch 1244: loss 0.133860
# model saved to ./save/ckpt-1244
# batch 1245: loss 0.071922
# model saved to ./save/ckpt-1245
# batch 1246: loss 0.188484
# model saved to ./save/ckpt-1246
# batch 1247: loss 0.326912
# model saved to ./save/ckpt-1247
# batch 1248: loss 0.131381
# model saved to ./save/ckpt-1248
# batch 1249: loss 0.191480
# model saved to ./save/ckpt-1249
# batch 1250: loss 0.119044
# model saved to ./save/ckpt-1250
# batch 1251: loss 0.275548
# model saved to ./save/ckpt-1251
# batch 1252: loss 0.298305
# model saved to ./save/ckpt-1252
# batch 1253: loss 0.199459
# model saved to ./save/ckpt-1253
# batch 1254: loss 0.327433
# model saved to ./save/ckpt-1254
# batch 1255: loss 0.202150
# model saved to ./save/ckpt-1255
# batch 1256: loss 0.062941
# model saved to ./save/ckpt-1256
# batch 1257: loss 0.140170
# model saved to ./save/ckpt-1257
# batch 1258: loss 0.369028
# model saved to ./save/ckpt-1258
# batch 1259: loss 0.062910
# model saved to ./save/ckpt-1259
# batch 1260: loss 0.155518
# model saved to ./save/ckpt-1260
# batch 1261: loss 0.182530
# model saved to ./save/ckpt-1261
# batch 1262: loss 0.216348
# model saved to ./save/ckpt-1262
# batch 1263: loss 0.090852
# model saved to ./save/ckpt-1263
# batch 1264: loss 0.094861
# model saved to ./save/ckpt-1264
# batch 1265: loss 0.170591
# model saved to ./save/ckpt-1265
# batch 1266: loss 0.108048
# model saved to ./save/ckpt-1266
# batch 1267: loss 0.061456
# model saved to ./save/ckpt-1267
# batch 1268: loss 0.066152
# model saved to ./save/ckpt-1268
# batch 1269: loss 0.170344
# model saved to ./save/ckpt-1269
# batch 1270: loss 0.106169
# model saved to ./save/ckpt-1270
# batch 1271: loss 0.136786
# model saved to ./save/ckpt-1271
# batch 1272: loss 0.075002
# model saved to ./save/ckpt-1272
# batch 1273: loss 0.146898
# model saved to ./save/ckpt-1273
# batch 1274: loss 0.161205
# model saved to ./save/ckpt-1274
# batch 1275: loss 0.133255
# model saved to ./save/ckpt-1275
# batch 1276: loss 0.110954
# model saved to ./save/ckpt-1276
# batch 1277: loss 0.089986
# model saved to ./save/ckpt-1277
# batch 1278: loss 0.182704
# model saved to ./save/ckpt-1278
# batch 1279: loss 0.081866
# model saved to ./save/ckpt-1279
# batch 1280: loss 0.229290
# model saved to ./save/ckpt-1280
# batch 1281: loss 0.221278
# model saved to ./save/ckpt-1281
# batch 1282: loss 0.232804
# model saved to ./save/ckpt-1282
# batch 1283: loss 0.098907
# model saved to ./save/ckpt-1283
# batch 1284: loss 0.070818
# model saved to ./save/ckpt-1284
# batch 1285: loss 0.091018
# model saved to ./save/ckpt-1285
# batch 1286: loss 0.120832
# model saved to ./save/ckpt-1286
# batch 1287: loss 0.074078
# model saved to ./save/ckpt-1287
# batch 1288: loss 0.086414
# model saved to ./save/ckpt-1288
# batch 1289: loss 0.226238
# model saved to ./save/ckpt-1289
# batch 1290: loss 0.198477
# model saved to ./save/ckpt-1290
# batch 1291: loss 0.204705
# model saved to ./save/ckpt-1291
# batch 1292: loss 0.129355
# model saved to ./save/ckpt-1292
# batch 1293: loss 0.083217
# model saved to ./save/ckpt-1293
# batch 1294: loss 0.129884
# model saved to ./save/ckpt-1294
# batch 1295: loss 0.216555
# model saved to ./save/ckpt-1295
# batch 1296: loss 0.047294
# model saved to ./save/ckpt-1296
# batch 1297: loss 0.310403
# model saved to ./save/ckpt-1297
# batch 1298: loss 0.239244
# model saved to ./save/ckpt-1298
# batch 1299: loss 0.183793
# model saved to ./save/ckpt-1299
# batch 1300: loss 0.101681
# model saved to ./save/ckpt-1300
# batch 1301: loss 0.139688
# model saved to ./save/ckpt-1301
# batch 1302: loss 0.318684
# model saved to ./save/ckpt-1302
# batch 1303: loss 0.268010
# model saved to ./save/ckpt-1303
# batch 1304: loss 0.184093
# model saved to ./save/ckpt-1304
# batch 1305: loss 0.071021
# model saved to ./save/ckpt-1305
# batch 1306: loss 0.196830
# model saved to ./save/ckpt-1306
# batch 1307: loss 0.258728
# model saved to ./save/ckpt-1307
# batch 1308: loss 0.278884
# model saved to ./save/ckpt-1308
# batch 1309: loss 0.123283
# model saved to ./save/ckpt-1309
# batch 1310: loss 0.080086
# model saved to ./save/ckpt-1310
# batch 1311: loss 0.100453
# model saved to ./save/ckpt-1311
# batch 1312: loss 0.151047
# model saved to ./save/ckpt-1312
# batch 1313: loss 0.103784
# model saved to ./save/ckpt-1313
# batch 1314: loss 0.140183
# model saved to ./save/ckpt-1314
# batch 1315: loss 0.084052
# model saved to ./save/ckpt-1315
# batch 1316: loss 0.211148
# model saved to ./save/ckpt-1316
# batch 1317: loss 0.204443
# model saved to ./save/ckpt-1317
# batch 1318: loss 0.161143
# model saved to ./save/ckpt-1318
# batch 1319: loss 0.033024
# model saved to ./save/ckpt-1319
# batch 1320: loss 0.061214
# model saved to ./save/ckpt-1320
# batch 1321: loss 0.187175
# model saved to ./save/ckpt-1321
# batch 1322: loss 0.241474
# model saved to ./save/ckpt-1322
# batch 1323: loss 0.042886
# model saved to ./save/ckpt-1323
# batch 1324: loss 0.196615
# model saved to ./save/ckpt-1324
# batch 1325: loss 0.207841
# model saved to ./save/ckpt-1325
# batch 1326: loss 0.057656
# model saved to ./save/ckpt-1326
# batch 1327: loss 0.057411
# model saved to ./save/ckpt-1327
# batch 1328: loss 0.085265
# model saved to ./save/ckpt-1328
# batch 1329: loss 0.057859
# model saved to ./save/ckpt-1329
# batch 1330: loss 0.082336
# model saved to ./save/ckpt-1330
# batch 1331: loss 0.138195
# model saved to ./save/ckpt-1331
# batch 1332: loss 0.208388
# model saved to ./save/ckpt-1332
# batch 1333: loss 0.172689
# model saved to ./save/ckpt-1333
# batch 1334: loss 0.091528
# model saved to ./save/ckpt-1334
# batch 1335: loss 0.150939
# model saved to ./save/ckpt-1335
# batch 1336: loss 0.069003
# model saved to ./save/ckpt-1336
# batch 1337: loss 0.131116
# model saved to ./save/ckpt-1337
# batch 1338: loss 0.183439
# model saved to ./save/ckpt-1338
# batch 1339: loss 0.078362
# model saved to ./save/ckpt-1339
# batch 1340: loss 0.164031
# model saved to ./save/ckpt-1340
# batch 1341: loss 0.320093
# model saved to ./save/ckpt-1341
# batch 1342: loss 0.048853
# model saved to ./save/ckpt-1342
# batch 1343: loss 0.130598
# model saved to ./save/ckpt-1343
# batch 1344: loss 0.066234
# model saved to ./save/ckpt-1344
# batch 1345: loss 0.090243
# model saved to ./save/ckpt-1345
# batch 1346: loss 0.048820
# model saved to ./save/ckpt-1346
# batch 1347: loss 0.087526
# model saved to ./save/ckpt-1347
# batch 1348: loss 0.213636
# model saved to ./save/ckpt-1348
# batch 1349: loss 0.127736
# model saved to ./save/ckpt-1349
# batch 1350: loss 0.149104
# model saved to ./save/ckpt-1350
# batch 1351: loss 0.088987
# model saved to ./save/ckpt-1351
# batch 1352: loss 0.079373
# model saved to ./save/ckpt-1352
# batch 1353: loss 0.046949
# model saved to ./save/ckpt-1353
# batch 1354: loss 0.104925
# model saved to ./save/ckpt-1354
# batch 1355: loss 0.042639
# model saved to ./save/ckpt-1355
# batch 1356: loss 0.146281
# model saved to ./save/ckpt-1356
# batch 1357: loss 0.262654
# model saved to ./save/ckpt-1357
# batch 1358: loss 0.086343
# model saved to ./save/ckpt-1358
# batch 1359: loss 0.144192
# model saved to ./save/ckpt-1359
# batch 1360: loss 0.200269
# model saved to ./save/ckpt-1360
# batch 1361: loss 0.094908
# model saved to ./save/ckpt-1361
# batch 1362: loss 0.172528
# model saved to ./save/ckpt-1362
# batch 1363: loss 0.165080
# model saved to ./save/ckpt-1363
# batch 1364: loss 0.084546
# model saved to ./save/ckpt-1364
# batch 1365: loss 0.094513
# model saved to ./save/ckpt-1365
# batch 1366: loss 0.167855
# model saved to ./save/ckpt-1366
# batch 1367: loss 0.051624
# model saved to ./save/ckpt-1367
# batch 1368: loss 0.186792
# model saved to ./save/ckpt-1368
# batch 1369: loss 0.192749
# model saved to ./save/ckpt-1369
# batch 1370: loss 0.182414
# model saved to ./save/ckpt-1370
# batch 1371: loss 0.147698
# model saved to ./save/ckpt-1371
# batch 1372: loss 0.036892
# model saved to ./save/ckpt-1372
# batch 1373: loss 0.351841
# model saved to ./save/ckpt-1373
# batch 1374: loss 0.157808
# model saved to ./save/ckpt-1374
# batch 1375: loss 0.071123
# model saved to ./save/ckpt-1375
# batch 1376: loss 0.294087
# model saved to ./save/ckpt-1376
# batch 1377: loss 0.143749
# model saved to ./save/ckpt-1377
# batch 1378: loss 0.301097
# model saved to ./save/ckpt-1378
# batch 1379: loss 0.139897
# model saved to ./save/ckpt-1379
# batch 1380: loss 0.142090
# model saved to ./save/ckpt-1380
# batch 1381: loss 0.129549
# model saved to ./save/ckpt-1381
# batch 1382: loss 0.216251
# model saved to ./save/ckpt-1382
# batch 1383: loss 0.055633
# model saved to ./save/ckpt-1383
# batch 1384: loss 0.146836
# model saved to ./save/ckpt-1384
# batch 1385: loss 0.436431
# model saved to ./save/ckpt-1385
# batch 1386: loss 0.115669
# model saved to ./save/ckpt-1386
# batch 1387: loss 0.053162
# model saved to ./save/ckpt-1387
# batch 1388: loss 0.172306
# model saved to ./save/ckpt-1388
# batch 1389: loss 0.185735
# model saved to ./save/ckpt-1389
# batch 1390: loss 0.096711
# model saved to ./save/ckpt-1390
# batch 1391: loss 0.177228
# model saved to ./save/ckpt-1391
# batch 1392: loss 0.100035
# model saved to ./save/ckpt-1392
# batch 1393: loss 0.061787
# model saved to ./save/ckpt-1393
# batch 1394: loss 0.080270
# model saved to ./save/ckpt-1394
# batch 1395: loss 0.170189
# model saved to ./save/ckpt-1395
# batch 1396: loss 0.070200
# model saved to ./save/ckpt-1396
# batch 1397: loss 0.252007
# model saved to ./save/ckpt-1397
# batch 1398: loss 0.070214
# model saved to ./save/ckpt-1398
# batch 1399: loss 0.183922
# model saved to ./save/ckpt-1399
# batch 1400: loss 0.092103
# model saved to ./save/ckpt-1400
# batch 1401: loss 0.132096
# model saved to ./save/ckpt-1401
# batch 1402: loss 0.069279
# model saved to ./save/ckpt-1402
# batch 1403: loss 0.125633
# model saved to ./save/ckpt-1403
# batch 1404: loss 0.109284
# model saved to ./save/ckpt-1404
# batch 1405: loss 0.174937
# model saved to ./save/ckpt-1405
# batch 1406: loss 0.068928
# model saved to ./save/ckpt-1406
# batch 1407: loss 0.144741
# model saved to ./save/ckpt-1407
# batch 1408: loss 0.112519
# model saved to ./save/ckpt-1408
# batch 1409: loss 0.201618
# model saved to ./save/ckpt-1409
# batch 1410: loss 0.205919
# model saved to ./save/ckpt-1410
# batch 1411: loss 0.066451
# model saved to ./save/ckpt-1411
# batch 1412: loss 0.095372
# model saved to ./save/ckpt-1412
# batch 1413: loss 0.057090
# model saved to ./save/ckpt-1413
# batch 1414: loss 0.186684
# model saved to ./save/ckpt-1414
# batch 1415: loss 0.159942
# model saved to ./save/ckpt-1415
# batch 1416: loss 0.190632
# model saved to ./save/ckpt-1416
# batch 1417: loss 0.173288
# model saved to ./save/ckpt-1417
# batch 1418: loss 0.121898
# model saved to ./save/ckpt-1418
# batch 1419: loss 0.165358
# model saved to ./save/ckpt-1419
# batch 1420: loss 0.107280
# model saved to ./save/ckpt-1420
# batch 1421: loss 0.040574
# model saved to ./save/ckpt-1421
# batch 1422: loss 0.139003
# model saved to ./save/ckpt-1422
# batch 1423: loss 0.031696
# model saved to ./save/ckpt-1423
# batch 1424: loss 0.072981
# model saved to ./save/ckpt-1424
# batch 1425: loss 0.048640
# model saved to ./save/ckpt-1425
# batch 1426: loss 0.144370
# model saved to ./save/ckpt-1426
# batch 1427: loss 0.203617
# model saved to ./save/ckpt-1427
# batch 1428: loss 0.068062
# model saved to ./save/ckpt-1428
# batch 1429: loss 0.178593
# model saved to ./save/ckpt-1429
# batch 1430: loss 0.135089
# model saved to ./save/ckpt-1430
# batch 1431: loss 0.090028
# model saved to ./save/ckpt-1431
# batch 1432: loss 0.125748
# model saved to ./save/ckpt-1432
# batch 1433: loss 0.098246
# model saved to ./save/ckpt-1433
# batch 1434: loss 0.066869
# model saved to ./save/ckpt-1434
# batch 1435: loss 0.061483
# model saved to ./save/ckpt-1435
# batch 1436: loss 0.049746
# model saved to ./save/ckpt-1436
# batch 1437: loss 0.215623
# model saved to ./save/ckpt-1437
# batch 1438: loss 0.063175
# model saved to ./save/ckpt-1438
# batch 1439: loss 0.052542
# model saved to ./save/ckpt-1439
# batch 1440: loss 0.043851
# model saved to ./save/ckpt-1440
# batch 1441: loss 0.256333
# model saved to ./save/ckpt-1441
# batch 1442: loss 0.088609
# model saved to ./save/ckpt-1442
# batch 1443: loss 0.036631
# model saved to ./save/ckpt-1443
# batch 1444: loss 0.156745
# model saved to ./save/ckpt-1444
# batch 1445: loss 0.100380
# model saved to ./save/ckpt-1445
# batch 1446: loss 0.059060
# model saved to ./save/ckpt-1446
# batch 1447: loss 0.123000
# model saved to ./save/ckpt-1447
# batch 1448: loss 0.055587
# model saved to ./save/ckpt-1448
# batch 1449: loss 0.164890
# model saved to ./save/ckpt-1449
# batch 1450: loss 0.061299
# model saved to ./save/ckpt-1450
# batch 1451: loss 0.065791
# model saved to ./save/ckpt-1451
# batch 1452: loss 0.116938
# model saved to ./save/ckpt-1452
# batch 1453: loss 0.132396
# model saved to ./save/ckpt-1453
# batch 1454: loss 0.150620
# model saved to ./save/ckpt-1454
# batch 1455: loss 0.108334
# model saved to ./save/ckpt-1455
# batch 1456: loss 0.120241
# model saved to ./save/ckpt-1456
# batch 1457: loss 0.069162
# model saved to ./save/ckpt-1457
# batch 1458: loss 0.040909
# model saved to ./save/ckpt-1458
# batch 1459: loss 0.187201
# model saved to ./save/ckpt-1459
# batch 1460: loss 0.206447
# model saved to ./save/ckpt-1460
# batch 1461: loss 0.425316
# model saved to ./save/ckpt-1461
# batch 1462: loss 0.236417
# model saved to ./save/ckpt-1462
# batch 1463: loss 0.039151
# model saved to ./save/ckpt-1463
# batch 1464: loss 0.090291
# model saved to ./save/ckpt-1464
# batch 1465: loss 0.184451
# model saved to ./save/ckpt-1465
# batch 1466: loss 0.133906
# model saved to ./save/ckpt-1466
# batch 1467: loss 0.200841
# model saved to ./save/ckpt-1467
# batch 1468: loss 0.189290
# model saved to ./save/ckpt-1468
# batch 1469: loss 0.087666
# model saved to ./save/ckpt-1469
# batch 1470: loss 0.263067
# model saved to ./save/ckpt-1470
# batch 1471: loss 0.108366
# model saved to ./save/ckpt-1471
# batch 1472: loss 0.059926
# model saved to ./save/ckpt-1472
# batch 1473: loss 0.231394
# model saved to ./save/ckpt-1473
# batch 1474: loss 0.329154
# model saved to ./save/ckpt-1474
# batch 1475: loss 0.043635
# model saved to ./save/ckpt-1475
# batch 1476: loss 0.049021
# model saved to ./save/ckpt-1476
# batch 1477: loss 0.240916
# model saved to ./save/ckpt-1477
# batch 1478: loss 0.170722
# model saved to ./save/ckpt-1478
# batch 1479: loss 0.258773
# model saved to ./save/ckpt-1479
# batch 1480: loss 0.206964
# model saved to ./save/ckpt-1480
# batch 1481: loss 0.094075
# model saved to ./save/ckpt-1481
# batch 1482: loss 0.154759
# model saved to ./save/ckpt-1482
# batch 1483: loss 0.298674
# model saved to ./save/ckpt-1483
# batch 1484: loss 0.062178
# model saved to ./save/ckpt-1484
# batch 1485: loss 0.039730
# model saved to ./save/ckpt-1485
# batch 1486: loss 0.139064
# model saved to ./save/ckpt-1486
# batch 1487: loss 0.155803
# model saved to ./save/ckpt-1487
# batch 1488: loss 0.256564
# model saved to ./save/ckpt-1488
# batch 1489: loss 0.310673
# model saved to ./save/ckpt-1489
# batch 1490: loss 0.021827
# model saved to ./save/ckpt-1490
# batch 1491: loss 0.153856
# model saved to ./save/ckpt-1491
# batch 1492: loss 0.275197
# model saved to ./save/ckpt-1492
# batch 1493: loss 0.204395
# model saved to ./save/ckpt-1493
# batch 1494: loss 0.091454
# model saved to ./save/ckpt-1494
# batch 1495: loss 0.070542
# model saved to ./save/ckpt-1495
# batch 1496: loss 0.092753
# model saved to ./save/ckpt-1496
# batch 1497: loss 0.124390
# model saved to ./save/ckpt-1497
# batch 1498: loss 0.286672
# model saved to ./save/ckpt-1498
# batch 1499: loss 0.044244
# model saved to ./save/ckpt-1499
# batch 1500: loss 0.176003
# model saved to ./save/ckpt-1500
# batch 1501: loss 0.075664
# model saved to ./save/ckpt-1501
# batch 1502: loss 0.118645
# model saved to ./save/ckpt-1502
# batch 1503: loss 0.150204
# model saved to ./save/ckpt-1503
# batch 1504: loss 0.264434
# model saved to ./save/ckpt-1504
# batch 1505: loss 0.080107
# model saved to ./save/ckpt-1505
# batch 1506: loss 0.339681
# model saved to ./save/ckpt-1506
# batch 1507: loss 0.116352
# model saved to ./save/ckpt-1507
# batch 1508: loss 0.186225
# model saved to ./save/ckpt-1508
# batch 1509: loss 0.260417
# model saved to ./save/ckpt-1509
# batch 1510: loss 0.119632
# model saved to ./save/ckpt-1510
# batch 1511: loss 0.242286
# model saved to ./save/ckpt-1511
# batch 1512: loss 0.069597
# model saved to ./save/ckpt-1512
# batch 1513: loss 0.066952
# model saved to ./save/ckpt-1513
# batch 1514: loss 0.167770
# model saved to ./save/ckpt-1514
# batch 1515: loss 0.078339
# model saved to ./save/ckpt-1515
# batch 1516: loss 0.240141
# model saved to ./save/ckpt-1516
# batch 1517: loss 0.158325
# model saved to ./save/ckpt-1517
# batch 1518: loss 0.075679
# model saved to ./save/ckpt-1518
# batch 1519: loss 0.122813
# model saved to ./save/ckpt-1519
# batch 1520: loss 0.164979
# model saved to ./save/ckpt-1520
# batch 1521: loss 0.260470
# model saved to ./save/ckpt-1521
# batch 1522: loss 0.124780
# model saved to ./save/ckpt-1522
# batch 1523: loss 0.082952
# model saved to ./save/ckpt-1523
# batch 1524: loss 0.155300
# model saved to ./save/ckpt-1524
# batch 1525: loss 0.086051
# model saved to ./save/ckpt-1525
# batch 1526: loss 0.072616
# model saved to ./save/ckpt-1526
# batch 1527: loss 0.092703
# model saved to ./save/ckpt-1527
# batch 1528: loss 0.289592
# model saved to ./save/ckpt-1528
# batch 1529: loss 0.085102
# model saved to ./save/ckpt-1529
# batch 1530: loss 0.063952
# model saved to ./save/ckpt-1530
# batch 1531: loss 0.079761
# model saved to ./save/ckpt-1531
# batch 1532: loss 0.108434
# model saved to ./save/ckpt-1532
# batch 1533: loss 0.078882
# model saved to ./save/ckpt-1533
# batch 1534: loss 0.212090
# model saved to ./save/ckpt-1534
# batch 1535: loss 0.139195
# model saved to ./save/ckpt-1535
# batch 1536: loss 0.051129
# model saved to ./save/ckpt-1536
# batch 1537: loss 0.170000
# model saved to ./save/ckpt-1537
# batch 1538: loss 0.119154
# model saved to ./save/ckpt-1538
# batch 1539: loss 0.167419
# model saved to ./save/ckpt-1539
# batch 1540: loss 0.150456
# model saved to ./save/ckpt-1540
# batch 1541: loss 0.132154
# model saved to ./save/ckpt-1541
# batch 1542: loss 0.101943
# model saved to ./save/ckpt-1542
# batch 1543: loss 0.140131
# model saved to ./save/ckpt-1543
# batch 1544: loss 0.121434
# model saved to ./save/ckpt-1544
# batch 1545: loss 0.238719
# model saved to ./save/ckpt-1545
# batch 1546: loss 0.118016
# model saved to ./save/ckpt-1546
# batch 1547: loss 0.365833
# model saved to ./save/ckpt-1547
# batch 1548: loss 0.141160
# model saved to ./save/ckpt-1548
# batch 1549: loss 0.287913
# model saved to ./save/ckpt-1549
# batch 1550: loss 0.149524
# model saved to ./save/ckpt-1550
# batch 1551: loss 0.079957
# model saved to ./save/ckpt-1551
# batch 1552: loss 0.170935
# model saved to ./save/ckpt-1552
# batch 1553: loss 0.090779
# model saved to ./save/ckpt-1553
# batch 1554: loss 0.094766
# model saved to ./save/ckpt-1554
# batch 1555: loss 0.072389
# model saved to ./save/ckpt-1555
# batch 1556: loss 0.214735
# model saved to ./save/ckpt-1556
# batch 1557: loss 0.136012
# model saved to ./save/ckpt-1557
# batch 1558: loss 0.209138
# model saved to ./save/ckpt-1558
# batch 1559: loss 0.135446
# model saved to ./save/ckpt-1559
# batch 1560: loss 0.129206
# model saved to ./save/ckpt-1560
# batch 1561: loss 0.214859
# model saved to ./save/ckpt-1561
# batch 1562: loss 0.080081
# model saved to ./save/ckpt-1562
# batch 1563: loss 0.170161
# model saved to ./save/ckpt-1563
# batch 1564: loss 0.077353
# model saved to ./save/ckpt-1564
# batch 1565: loss 0.062399
# model saved to ./save/ckpt-1565
# batch 1566: loss 0.179846
# model saved to ./save/ckpt-1566
# batch 1567: loss 0.145055
# model saved to ./save/ckpt-1567
# batch 1568: loss 0.262204
# model saved to ./save/ckpt-1568
# batch 1569: loss 0.102139
# model saved to ./save/ckpt-1569
# batch 1570: loss 0.120923
# model saved to ./save/ckpt-1570
# batch 1571: loss 0.281938
# model saved to ./save/ckpt-1571
# batch 1572: loss 0.100184
# model saved to ./save/ckpt-1572
# batch 1573: loss 0.173630
# model saved to ./save/ckpt-1573
# batch 1574: loss 0.100046
# model saved to ./save/ckpt-1574
# batch 1575: loss 0.122688
# model saved to ./save/ckpt-1575
# batch 1576: loss 0.150191
# model saved to ./save/ckpt-1576
# batch 1577: loss 0.138911
# model saved to ./save/ckpt-1577
# batch 1578: loss 0.351677
# model saved to ./save/ckpt-1578
# batch 1579: loss 0.136576
# model saved to ./save/ckpt-1579
# batch 1580: loss 0.060366
# model saved to ./save/ckpt-1580
# batch 1581: loss 0.131295
# model saved to ./save/ckpt-1581
# batch 1582: loss 0.314383
# model saved to ./save/ckpt-1582
# batch 1583: loss 0.098962
# model saved to ./save/ckpt-1583
# batch 1584: loss 0.236149
# model saved to ./save/ckpt-1584
# batch 1585: loss 0.265087
# model saved to ./save/ckpt-1585
# batch 1586: loss 0.024986
# model saved to ./save/ckpt-1586
# batch 1587: loss 0.227257
# model saved to ./save/ckpt-1587
# batch 1588: loss 0.177363
# model saved to ./save/ckpt-1588
# batch 1589: loss 0.143547
# model saved to ./save/ckpt-1589
# batch 1590: loss 0.186075
# model saved to ./save/ckpt-1590
# batch 1591: loss 0.087681
# model saved to ./save/ckpt-1591
# batch 1592: loss 0.129594
# model saved to ./save/ckpt-1592
# batch 1593: loss 0.143162
# model saved to ./save/ckpt-1593
# batch 1594: loss 0.130373
# model saved to ./save/ckpt-1594
# batch 1595: loss 0.172976
# model saved to ./save/ckpt-1595
# batch 1596: loss 0.077670
# model saved to ./save/ckpt-1596
# batch 1597: loss 0.046252
# model saved to ./save/ckpt-1597
# batch 1598: loss 0.212787
# model saved to ./save/ckpt-1598
# batch 1599: loss 0.116172
# model saved to ./save/ckpt-1599
# batch 1600: loss 0.184172
# model saved to ./save/ckpt-1600
# batch 1601: loss 0.140850
# model saved to ./save/ckpt-1601
# batch 1602: loss 0.193106
# model saved to ./save/ckpt-1602
# batch 1603: loss 0.103170
# model saved to ./save/ckpt-1603
# batch 1604: loss 0.098645
# model saved to ./save/ckpt-1604
# batch 1605: loss 0.192707
# model saved to ./save/ckpt-1605
# batch 1606: loss 0.201727
# model saved to ./save/ckpt-1606
# batch 1607: loss 0.117380
# model saved to ./save/ckpt-1607
# batch 1608: loss 0.146938
# model saved to ./save/ckpt-1608
# batch 1609: loss 0.133073
# model saved to ./save/ckpt-1609
# batch 1610: loss 0.175694
# model saved to ./save/ckpt-1610
# batch 1611: loss 0.089575
# model saved to ./save/ckpt-1611
# batch 1612: loss 0.097952
# model saved to ./save/ckpt-1612
# batch 1613: loss 0.157022
# model saved to ./save/ckpt-1613
# batch 1614: loss 0.287253
# model saved to ./save/ckpt-1614
# batch 1615: loss 0.070504
# model saved to ./save/ckpt-1615
# batch 1616: loss 0.091780
# model saved to ./save/ckpt-1616
# batch 1617: loss 0.149691
# model saved to ./save/ckpt-1617
# batch 1618: loss 0.193014
# model saved to ./save/ckpt-1618
# batch 1619: loss 0.137452
# model saved to ./save/ckpt-1619
# batch 1620: loss 0.152434
# model saved to ./save/ckpt-1620
# batch 1621: loss 0.029048
# model saved to ./save/ckpt-1621
# batch 1622: loss 0.107884
# model saved to ./save/ckpt-1622
# batch 1623: loss 0.162595
# model saved to ./save/ckpt-1623
# batch 1624: loss 0.124519
# model saved to ./save/ckpt-1624
# batch 1625: loss 0.104938
# model saved to ./save/ckpt-1625
# batch 1626: loss 0.181144
# model saved to ./save/ckpt-1626
# batch 1627: loss 0.178467
# model saved to ./save/ckpt-1627
# batch 1628: loss 0.047958
# model saved to ./save/ckpt-1628
# batch 1629: loss 0.094653
# model saved to ./save/ckpt-1629
# batch 1630: loss 0.146205
# model saved to ./save/ckpt-1630
# batch 1631: loss 0.153568
# model saved to ./save/ckpt-1631
# batch 1632: loss 0.039161
# model saved to ./save/ckpt-1632
# batch 1633: loss 0.206352
# model saved to ./save/ckpt-1633
# batch 1634: loss 0.120606
# model saved to ./save/ckpt-1634
# batch 1635: loss 0.029565
# model saved to ./save/ckpt-1635
# batch 1636: loss 0.147371
# model saved to ./save/ckpt-1636
# batch 1637: loss 0.055444
# model saved to ./save/ckpt-1637
# batch 1638: loss 0.367033
# model saved to ./save/ckpt-1638
# batch 1639: loss 0.131999
# model saved to ./save/ckpt-1639
# batch 1640: loss 0.077482
# model saved to ./save/ckpt-1640
# batch 1641: loss 0.087332
# model saved to ./save/ckpt-1641
# batch 1642: loss 0.182661
# model saved to ./save/ckpt-1642
# batch 1643: loss 0.027429
# model saved to ./save/ckpt-1643
# batch 1644: loss 0.143112
# model saved to ./save/ckpt-1644
# batch 1645: loss 0.125006
# model saved to ./save/ckpt-1645
# batch 1646: loss 0.101229
# model saved to ./save/ckpt-1646
# batch 1647: loss 0.178272
# model saved to ./save/ckpt-1647
# batch 1648: loss 0.178092
# model saved to ./save/ckpt-1648
# batch 1649: loss 0.171734
# model saved to ./save/ckpt-1649
# batch 1650: loss 0.102418
# model saved to ./save/ckpt-1650
# batch 1651: loss 0.244645
# model saved to ./save/ckpt-1651
# batch 1652: loss 0.141024
# model saved to ./save/ckpt-1652
# batch 1653: loss 0.189008
# model saved to ./save/ckpt-1653
# batch 1654: loss 0.051102
# model saved to ./save/ckpt-1654
# batch 1655: loss 0.381347
# model saved to ./save/ckpt-1655
# batch 1656: loss 0.157426
# model saved to ./save/ckpt-1656
# batch 1657: loss 0.156835
# model saved to ./save/ckpt-1657
# batch 1658: loss 0.067864
# model saved to ./save/ckpt-1658
# batch 1659: loss 0.167071
# model saved to ./save/ckpt-1659
# batch 1660: loss 0.070727
# model saved to ./save/ckpt-1660
# batch 1661: loss 0.168041
# model saved to ./save/ckpt-1661
# batch 1662: loss 0.237288
# model saved to ./save/ckpt-1662
# batch 1663: loss 0.128716
# model saved to ./save/ckpt-1663
# batch 1664: loss 0.055032
# model saved to ./save/ckpt-1664
# batch 1665: loss 0.102613
# model saved to ./save/ckpt-1665
# batch 1666: loss 0.291146
# model saved to ./save/ckpt-1666
# batch 1667: loss 0.050229
# model saved to ./save/ckpt-1667
# batch 1668: loss 0.158263
# model saved to ./save/ckpt-1668
# batch 1669: loss 0.032996
# model saved to ./save/ckpt-1669
# batch 1670: loss 0.054382
# model saved to ./save/ckpt-1670
# batch 1671: loss 0.142422
# model saved to ./save/ckpt-1671
# batch 1672: loss 0.146187
# model saved to ./save/ckpt-1672
# batch 1673: loss 0.314634
# model saved to ./save/ckpt-1673
# batch 1674: loss 0.194017
# model saved to ./save/ckpt-1674
# batch 1675: loss 0.075803
# model saved to ./save/ckpt-1675
# batch 1676: loss 0.239175
# model saved to ./save/ckpt-1676
# batch 1677: loss 0.032174
# model saved to ./save/ckpt-1677
# batch 1678: loss 0.077936
# model saved to ./save/ckpt-1678
# batch 1679: loss 0.158934
# model saved to ./save/ckpt-1679
# batch 1680: loss 0.355131
# model saved to ./save/ckpt-1680
# batch 1681: loss 0.039196
# model saved to ./save/ckpt-1681
# batch 1682: loss 0.051969
# model saved to ./save/ckpt-1682
# batch 1683: loss 0.158476
# model saved to ./save/ckpt-1683
# batch 1684: loss 0.077840
# model saved to ./save/ckpt-1684
# batch 1685: loss 0.152329
# model saved to ./save/ckpt-1685
# batch 1686: loss 0.220106
# model saved to ./save/ckpt-1686
# batch 1687: loss 0.045100
# model saved to ./save/ckpt-1687
# batch 1688: loss 0.176953
# model saved to ./save/ckpt-1688
# batch 1689: loss 0.199431
# model saved to ./save/ckpt-1689
# batch 1690: loss 0.136517
# model saved to ./save/ckpt-1690
# batch 1691: loss 0.071213
# model saved to ./save/ckpt-1691
# batch 1692: loss 0.036422
# model saved to ./save/ckpt-1692
# batch 1693: loss 0.151581
# model saved to ./save/ckpt-1693
# batch 1694: loss 0.129078
# model saved to ./save/ckpt-1694
# batch 1695: loss 0.287378
# model saved to ./save/ckpt-1695
# batch 1696: loss 0.137585
# model saved to ./save/ckpt-1696
# batch 1697: loss 0.111325
# model saved to ./save/ckpt-1697
# batch 1698: loss 0.036806
# model saved to ./save/ckpt-1698
# batch 1699: loss 0.189986
# model saved to ./save/ckpt-1699
# batch 1700: loss 0.072805
# model saved to ./save/ckpt-1700
# batch 1701: loss 0.113597
# model saved to ./save/ckpt-1701
# batch 1702: loss 0.286304
# model saved to ./save/ckpt-1702
# batch 1703: loss 0.255719
# model saved to ./save/ckpt-1703
# batch 1704: loss 0.072128
# model saved to ./save/ckpt-1704
# batch 1705: loss 0.176378
# model saved to ./save/ckpt-1705
# batch 1706: loss 0.111957
# model saved to ./save/ckpt-1706
# batch 1707: loss 0.168256
# model saved to ./save/ckpt-1707
# batch 1708: loss 0.074548
# model saved to ./save/ckpt-1708
# batch 1709: loss 0.343092
# model saved to ./save/ckpt-1709
# batch 1710: loss 0.137984
# model saved to ./save/ckpt-1710
# batch 1711: loss 0.083173
# model saved to ./save/ckpt-1711
# batch 1712: loss 0.290085
# model saved to ./save/ckpt-1712
# batch 1713: loss 0.162366
# model saved to ./save/ckpt-1713
# batch 1714: loss 0.085398
# model saved to ./save/ckpt-1714
# batch 1715: loss 0.076084
# model saved to ./save/ckpt-1715
# batch 1716: loss 0.048696
# model saved to ./save/ckpt-1716
# batch 1717: loss 0.215457
# model saved to ./save/ckpt-1717
# batch 1718: loss 0.101410
# model saved to ./save/ckpt-1718
# batch 1719: loss 0.161945
# model saved to ./save/ckpt-1719
# batch 1720: loss 0.092233
# model saved to ./save/ckpt-1720
# batch 1721: loss 0.083578
# model saved to ./save/ckpt-1721
# batch 1722: loss 0.119225
# model saved to ./save/ckpt-1722
# batch 1723: loss 0.099766
# model saved to ./save/ckpt-1723
# batch 1724: loss 0.184556
# model saved to ./save/ckpt-1724
# batch 1725: loss 0.105704
# model saved to ./save/ckpt-1725
# batch 1726: loss 0.138401
# model saved to ./save/ckpt-1726
# batch 1727: loss 0.114512
# model saved to ./save/ckpt-1727
# batch 1728: loss 0.100968
# model saved to ./save/ckpt-1728
# batch 1729: loss 0.083940
# model saved to ./save/ckpt-1729
# batch 1730: loss 0.066517
# model saved to ./save/ckpt-1730
# batch 1731: loss 0.169266
# model saved to ./save/ckpt-1731
# batch 1732: loss 0.245388
# model saved to ./save/ckpt-1732
# batch 1733: loss 0.053238
# model saved to ./save/ckpt-1733
# batch 1734: loss 0.041185
# model saved to ./save/ckpt-1734
# batch 1735: loss 0.246760
# model saved to ./save/ckpt-1735
# batch 1736: loss 0.212988
# model saved to ./save/ckpt-1736
# batch 1737: loss 0.111352
# model saved to ./save/ckpt-1737
# batch 1738: loss 0.190739
# model saved to ./save/ckpt-1738
# batch 1739: loss 0.082998
# model saved to ./save/ckpt-1739
# batch 1740: loss 0.081870
# model saved to ./save/ckpt-1740
# batch 1741: loss 0.064418
# model saved to ./save/ckpt-1741
# batch 1742: loss 0.098867
# model saved to ./save/ckpt-1742
# batch 1743: loss 0.123716
# model saved to ./save/ckpt-1743
# batch 1744: loss 0.265256
# model saved to ./save/ckpt-1744
# batch 1745: loss 0.059576
# model saved to ./save/ckpt-1745
# batch 1746: loss 0.100142
# model saved to ./save/ckpt-1746
# batch 1747: loss 0.124357
# model saved to ./save/ckpt-1747
# batch 1748: loss 0.143524
# model saved to ./save/ckpt-1748
# batch 1749: loss 0.217134
# model saved to ./save/ckpt-1749
# batch 1750: loss 0.142773
# model saved to ./save/ckpt-1750
# batch 1751: loss 0.039701
# model saved to ./save/ckpt-1751
# batch 1752: loss 0.150284
# model saved to ./save/ckpt-1752
# batch 1753: loss 0.127335
# model saved to ./save/ckpt-1753
# batch 1754: loss 0.064923
# model saved to ./save/ckpt-1754
# batch 1755: loss 0.314916
# model saved to ./save/ckpt-1755
# batch 1756: loss 0.081969
# model saved to ./save/ckpt-1756
# batch 1757: loss 0.184101
# model saved to ./save/ckpt-1757
# batch 1758: loss 0.087577
# model saved to ./save/ckpt-1758
# batch 1759: loss 0.045047
# model saved to ./save/ckpt-1759
# batch 1760: loss 0.155807
# model saved to ./save/ckpt-1760
# batch 1761: loss 0.138552
# model saved to ./save/ckpt-1761
# batch 1762: loss 0.047780
# model saved to ./save/ckpt-1762
# batch 1763: loss 0.169920
# model saved to ./save/ckpt-1763
# batch 1764: loss 0.254860
# model saved to ./save/ckpt-1764
# batch 1765: loss 0.021926
# model saved to ./save/ckpt-1765
# batch 1766: loss 0.162868
# model saved to ./save/ckpt-1766
# batch 1767: loss 0.276944
# model saved to ./save/ckpt-1767
# batch 1768: loss 0.040098
# model saved to ./save/ckpt-1768
# batch 1769: loss 0.042005
# model saved to ./save/ckpt-1769
# batch 1770: loss 0.042406
# model saved to ./save/ckpt-1770
# batch 1771: loss 0.129769
# model saved to ./save/ckpt-1771
# batch 1772: loss 0.044203
# model saved to ./save/ckpt-1772
# batch 1773: loss 0.137990
# model saved to ./save/ckpt-1773
# batch 1774: loss 0.107043
# model saved to ./save/ckpt-1774
# batch 1775: loss 0.147516
# model saved to ./save/ckpt-1775
# batch 1776: loss 0.162425
# model saved to ./save/ckpt-1776
# batch 1777: loss 0.192605
# model saved to ./save/ckpt-1777
# batch 1778: loss 0.166265
# model saved to ./save/ckpt-1778
# batch 1779: loss 0.092679
# model saved to ./save/ckpt-1779
# batch 1780: loss 0.306383
# model saved to ./save/ckpt-1780
# batch 1781: loss 0.175429
# model saved to ./save/ckpt-1781
# batch 1782: loss 0.115099
# model saved to ./save/ckpt-1782
# batch 1783: loss 0.138303
# model saved to ./save/ckpt-1783
# batch 1784: loss 0.140351
# model saved to ./save/ckpt-1784
# batch 1785: loss 0.121226
# model saved to ./save/ckpt-1785
# batch 1786: loss 0.188294
# model saved to ./save/ckpt-1786
# batch 1787: loss 0.117945
# model saved to ./save/ckpt-1787
# batch 1788: loss 0.078446
# model saved to ./save/ckpt-1788
# batch 1789: loss 0.092083
# model saved to ./save/ckpt-1789
# batch 1790: loss 0.146309
# model saved to ./save/ckpt-1790
# batch 1791: loss 0.077769
# model saved to ./save/ckpt-1791
# batch 1792: loss 0.120598
# model saved to ./save/ckpt-1792
# batch 1793: loss 0.091753
# model saved to ./save/ckpt-1793
# batch 1794: loss 0.103165
# model saved to ./save/ckpt-1794
# batch 1795: loss 0.044753
# model saved to ./save/ckpt-1795
# batch 1796: loss 0.074424
# model saved to ./save/ckpt-1796
# batch 1797: loss 0.201538
# model saved to ./save/ckpt-1797
# batch 1798: loss 0.061915
# model saved to ./save/ckpt-1798
# batch 1799: loss 0.111404
# model saved to ./save/ckpt-1799
# batch 1800: loss 0.104669
# model saved to ./save/ckpt-1800
# batch 1801: loss 0.164688
# model saved to ./save/ckpt-1801
# batch 1802: loss 0.033949
# model saved to ./save/ckpt-1802
# batch 1803: loss 0.130594
# model saved to ./save/ckpt-1803
# batch 1804: loss 0.038074
# model saved to ./save/ckpt-1804
# batch 1805: loss 0.077809
# model saved to ./save/ckpt-1805
# batch 1806: loss 0.042424
# model saved to ./save/ckpt-1806
# batch 1807: loss 0.114568
# model saved to ./save/ckpt-1807
# batch 1808: loss 0.149513
# model saved to ./save/ckpt-1808
# batch 1809: loss 0.061151
# model saved to ./save/ckpt-1809
# batch 1810: loss 0.060218
# model saved to ./save/ckpt-1810
# batch 1811: loss 0.305959
# model saved to ./save/ckpt-1811
# batch 1812: loss 0.245932
# model saved to ./save/ckpt-1812
# batch 1813: loss 0.069500
# model saved to ./save/ckpt-1813
# batch 1814: loss 0.139447
# model saved to ./save/ckpt-1814
# batch 1815: loss 0.088705
# model saved to ./save/ckpt-1815
# batch 1816: loss 0.195318
# model saved to ./save/ckpt-1816
# batch 1817: loss 0.269930
# model saved to ./save/ckpt-1817
# batch 1818: loss 0.110110
# model saved to ./save/ckpt-1818
# batch 1819: loss 0.042192
# model saved to ./save/ckpt-1819
# batch 1820: loss 0.150924
# model saved to ./save/ckpt-1820
# batch 1821: loss 0.180057
# model saved to ./save/ckpt-1821
# batch 1822: loss 0.108073
# model saved to ./save/ckpt-1822
# batch 1823: loss 0.075036
# model saved to ./save/ckpt-1823
# batch 1824: loss 0.170707
# model saved to ./save/ckpt-1824
# batch 1825: loss 0.067660
# model saved to ./save/ckpt-1825
# batch 1826: loss 0.303612
# model saved to ./save/ckpt-1826
# batch 1827: loss 0.160064
# model saved to ./save/ckpt-1827
# batch 1828: loss 0.128754
# model saved to ./save/ckpt-1828
# batch 1829: loss 0.051353
# model saved to ./save/ckpt-1829
# batch 1830: loss 0.102880
# model saved to ./save/ckpt-1830
# batch 1831: loss 0.301955
# model saved to ./save/ckpt-1831
# batch 1832: loss 0.043484
# model saved to ./save/ckpt-1832
# batch 1833: loss 0.105477
# model saved to ./save/ckpt-1833
# batch 1834: loss 0.085647
# model saved to ./save/ckpt-1834
# batch 1835: loss 0.041815
# model saved to ./save/ckpt-1835
# batch 1836: loss 0.255897
# model saved to ./save/ckpt-1836
# batch 1837: loss 0.137971
# model saved to ./save/ckpt-1837
# batch 1838: loss 0.163275
# model saved to ./save/ckpt-1838
# batch 1839: loss 0.049205
# model saved to ./save/ckpt-1839
# batch 1840: loss 0.187455
# model saved to ./save/ckpt-1840
# batch 1841: loss 0.152473
# model saved to ./save/ckpt-1841
# batch 1842: loss 0.144690
# model saved to ./save/ckpt-1842
# batch 1843: loss 0.063477
# model saved to ./save/ckpt-1843
# batch 1844: loss 0.066883
# model saved to ./save/ckpt-1844
# batch 1845: loss 0.081166
# model saved to ./save/ckpt-1845
# batch 1846: loss 0.088978
# model saved to ./save/ckpt-1846
# batch 1847: loss 0.100220
# model saved to ./save/ckpt-1847
# batch 1848: loss 0.115445
# model saved to ./save/ckpt-1848
# batch 1849: loss 0.083929
# model saved to ./save/ckpt-1849
# batch 1850: loss 0.047721
# model saved to ./save/ckpt-1850
# batch 1851: loss 0.124183
# model saved to ./save/ckpt-1851
# batch 1852: loss 0.105605
# model saved to ./save/ckpt-1852
# batch 1853: loss 0.310122
# model saved to ./save/ckpt-1853
# batch 1854: loss 0.094505
# model saved to ./save/ckpt-1854
# batch 1855: loss 0.088534
# model saved to ./save/ckpt-1855
# batch 1856: loss 0.057069
# model saved to ./save/ckpt-1856
# batch 1857: loss 0.140052
# model saved to ./save/ckpt-1857
# batch 1858: loss 0.022617
# model saved to ./save/ckpt-1858
# batch 1859: loss 0.112675
# model saved to ./save/ckpt-1859
# batch 1860: loss 0.118003
# model saved to ./save/ckpt-1860
# batch 1861: loss 0.050396
# model saved to ./save/ckpt-1861
# batch 1862: loss 0.089232
# model saved to ./save/ckpt-1862
# batch 1863: loss 0.253751
# model saved to ./save/ckpt-1863
# batch 1864: loss 0.113814
# model saved to ./save/ckpt-1864
# batch 1865: loss 0.146397
# model saved to ./save/ckpt-1865
# batch 1866: loss 0.178271
# model saved to ./save/ckpt-1866
# batch 1867: loss 0.033279
# model saved to ./save/ckpt-1867
# batch 1868: loss 0.170524
# model saved to ./save/ckpt-1868
# batch 1869: loss 0.188201
# model saved to ./save/ckpt-1869
# batch 1870: loss 0.052837
# model saved to ./save/ckpt-1870
# batch 1871: loss 0.210295
# model saved to ./save/ckpt-1871
# batch 1872: loss 0.295511
# model saved to ./save/ckpt-1872
# batch 1873: loss 0.046482
# model saved to ./save/ckpt-1873
# batch 1874: loss 0.092590
# model saved to ./save/ckpt-1874
# batch 1875: loss 0.084570
# model saved to ./save/ckpt-1875
# batch 1876: loss 0.071252
# model saved to ./save/ckpt-1876
# batch 1877: loss 0.052174
# model saved to ./save/ckpt-1877
# batch 1878: loss 0.186059
# model saved to ./save/ckpt-1878
# batch 1879: loss 0.246072
# model saved to ./save/ckpt-1879
# batch 1880: loss 0.059971
# model saved to ./save/ckpt-1880
# batch 1881: loss 0.035216
# model saved to ./save/ckpt-1881
# batch 1882: loss 0.047292
# model saved to ./save/ckpt-1882
# batch 1883: loss 0.077909
# model saved to ./save/ckpt-1883
# batch 1884: loss 0.317461
# model saved to ./save/ckpt-1884
# batch 1885: loss 0.118996
# model saved to ./save/ckpt-1885
# batch 1886: loss 0.124943
# model saved to ./save/ckpt-1886
# batch 1887: loss 0.048308
# model saved to ./save/ckpt-1887
# batch 1888: loss 0.104334
# model saved to ./save/ckpt-1888
# batch 1889: loss 0.082734
# model saved to ./save/ckpt-1889
# batch 1890: loss 0.187792
# model saved to ./save/ckpt-1890
# batch 1891: loss 0.137109
# model saved to ./save/ckpt-1891
# batch 1892: loss 0.056891
# model saved to ./save/ckpt-1892
# batch 1893: loss 0.097364
# model saved to ./save/ckpt-1893
# batch 1894: loss 0.192138
# model saved to ./save/ckpt-1894
# batch 1895: loss 0.040633
# model saved to ./save/ckpt-1895
# batch 1896: loss 0.128901
# model saved to ./save/ckpt-1896
# batch 1897: loss 0.086160
# model saved to ./save/ckpt-1897
# batch 1898: loss 0.196403
# model saved to ./save/ckpt-1898
# batch 1899: loss 0.110997
# model saved to ./save/ckpt-1899
# batch 1900: loss 0.265675
# model saved to ./save/ckpt-1900
# batch 1901: loss 0.148888
# model saved to ./save/ckpt-1901
# batch 1902: loss 0.036643
# model saved to ./save/ckpt-1902
# batch 1903: loss 0.184072
# model saved to ./save/ckpt-1903
# batch 1904: loss 0.077712
# model saved to ./save/ckpt-1904
# batch 1905: loss 0.077929
# model saved to ./save/ckpt-1905
# batch 1906: loss 0.188394
# model saved to ./save/ckpt-1906
# batch 1907: loss 0.048903
# model saved to ./save/ckpt-1907
# batch 1908: loss 0.019540
# model saved to ./save/ckpt-1908
# batch 1909: loss 0.096928
# model saved to ./save/ckpt-1909
# batch 1910: loss 0.060602
# model saved to ./save/ckpt-1910
# batch 1911: loss 0.099751
# model saved to ./save/ckpt-1911
# batch 1912: loss 0.096396
# model saved to ./save/ckpt-1912
# batch 1913: loss 0.086990
# model saved to ./save/ckpt-1913
# batch 1914: loss 0.087189
# model saved to ./save/ckpt-1914
# batch 1915: loss 0.038351
# model saved to ./save/ckpt-1915
# batch 1916: loss 0.082921
# model saved to ./save/ckpt-1916
# batch 1917: loss 0.089887
# model saved to ./save/ckpt-1917
# batch 1918: loss 0.053057
# model saved to ./save/ckpt-1918
# batch 1919: loss 0.310410
# model saved to ./save/ckpt-1919
# batch 1920: loss 0.113419
# model saved to ./save/ckpt-1920
# ...
# model saved to ./save/ckpt-3364
# batch 3365: loss 0.071128
# model saved to ./save/ckpt-3365
# batch 3366: loss 0.087415
# model saved to ./save/ckpt-3366
# batch 3367: loss 0.050649
# model saved to ./save/ckpt-3367
# batch 3368: loss 0.028324
# model saved to ./save/ckpt-3368
# batch 3369: loss 0.051625
# model saved to ./save/ckpt-3369
# batch 3370: loss 0.060659
# model saved to ./save/ckpt-3370
# batch 3371: loss 0.127120
# model saved to ./save/ckpt-3371
# batch 3372: loss 0.044398
# model saved to ./save/ckpt-3372
# batch 3373: loss 0.231432
# model saved to ./save/ckpt-3373
# batch 3374: loss 0.068218
# model saved to ./save/ckpt-3374
# batch 3375: loss 0.013918
# model saved to ./save/ckpt-3375
# batch 3376: loss 0.099405
# model saved to ./save/ckpt-3376
# batch 3377: loss 0.134485
# model saved to ./save/ckpt-3377
# batch 3378: loss 0.051588
# model saved to ./save/ckpt-3378
# batch 3379: loss 0.045970
# model saved to ./save/ckpt-3379
# batch 3380: loss 0.077252
# model saved to ./save/ckpt-3380
# batch 3381: loss 0.031165
# model saved to ./save/ckpt-3381
# batch 3382: loss 0.021650
# model saved to ./save/ckpt-3382
# batch 3383: loss 0.054010
# model saved to ./save/ckpt-3383
# batch 3384: loss 0.041272
# model saved to ./save/ckpt-3384
# batch 3385: loss 0.063119
# model saved to ./save/ckpt-3385
# batch 3386: loss 0.090175
# model saved to ./save/ckpt-3386
# batch 3387: loss 0.048333
# model saved to ./save/ckpt-3387
# batch 3388: loss 0.057185
# model saved to ./save/ckpt-3388
# batch 3389: loss 0.199100
# model saved to ./save/ckpt-3389
# batch 3390: loss 0.097838
# model saved to ./save/ckpt-3390
# batch 3391: loss 0.068367
# model saved to ./save/ckpt-3391
# batch 3392: loss 0.031115
# model saved to ./save/ckpt-3392
# batch 3393: loss 0.020852
# model saved to ./save/ckpt-3393
# batch 3394: loss 0.019769
# model saved to ./save/ckpt-3394
# batch 3395: loss 0.102431
# model saved to ./save/ckpt-3395
# batch 3396: loss 0.152635
# model saved to ./save/ckpt-3396
# batch 3397: loss 0.169566
# model saved to ./save/ckpt-3397
# batch 3398: loss 0.032984
# model saved to ./save/ckpt-3398
# batch 3399: loss 0.040331
# model saved to ./save/ckpt-3399
# batch 3400: loss 0.019883
# model saved to ./save/ckpt-3400
# batch 3401: loss 0.030653
# model saved to ./save/ckpt-3401
# batch 3402: loss 0.044614
# model saved to ./save/ckpt-3402
# batch 3403: loss 0.093375
# model saved to ./save/ckpt-3403
# batch 3404: loss 0.133640
# model saved to ./save/ckpt-3404
# batch 3405: loss 0.222519
# model saved to ./save/ckpt-3405
# batch 3406: loss 0.028711
# model saved to ./save/ckpt-3406
# batch 3407: loss 0.108361
# model saved to ./save/ckpt-3407
# batch 3408: loss 0.049680
# model saved to ./save/ckpt-3408
# batch 3409: loss 0.147914
# model saved to ./save/ckpt-3409
# batch 3410: loss 0.121297
# model saved to ./save/ckpt-3410
# batch 3411: loss 0.069656
# model saved to ./save/ckpt-3411
# batch 3412: loss 0.026621
# model saved to ./save/ckpt-3412
# batch 3413: loss 0.132257
# model saved to ./save/ckpt-3413
# batch 3414: loss 0.051273
# model saved to ./save/ckpt-3414
# batch 3415: loss 0.103271
# model saved to ./save/ckpt-3415
# batch 3416: loss 0.031067
# model saved to ./save/ckpt-3416
# batch 3417: loss 0.035790
# model saved to ./save/ckpt-3417
# batch 3418: loss 0.046358
# model saved to ./save/ckpt-3418
# batch 3419: loss 0.043324
# model saved to ./save/ckpt-3419
# batch 3420: loss 0.064426
# model saved to ./save/ckpt-3420
# batch 3421: loss 0.168349
# model saved to ./save/ckpt-3421
# batch 3422: loss 0.213342
# model saved to ./save/ckpt-3422
# batch 3423: loss 0.016861
# model saved to ./save/ckpt-3423
# batch 3424: loss 0.043714
# model saved to ./save/ckpt-3424
# batch 3425: loss 0.075262
# model saved to ./save/ckpt-3425
# batch 3426: loss 0.076172
# model saved to ./save/ckpt-3426
# batch 3427: loss 0.025924
# model saved to ./save/ckpt-3427
# batch 3428: loss 0.013663
# model saved to ./save/ckpt-3428
# batch 3429: loss 0.034651
# model saved to ./save/ckpt-3429
# batch 3430: loss 0.068205
# model saved to ./save/ckpt-3430
# batch 3431: loss 0.015133
# model saved to ./save/ckpt-3431
# batch 3432: loss 0.076520
# model saved to ./save/ckpt-3432
# batch 3433: loss 0.068629
# model saved to ./save/ckpt-3433
# batch 3434: loss 0.081094
# model saved to ./save/ckpt-3434
# batch 3435: loss 0.040209
# model saved to ./save/ckpt-3435
# batch 3436: loss 0.103073
# model saved to ./save/ckpt-3436
# batch 3437: loss 0.098325
# model saved to ./save/ckpt-3437
# batch 3438: loss 0.140568
# model saved to ./save/ckpt-3438
# batch 3439: loss 0.124488
# model saved to ./save/ckpt-3439
# batch 3440: loss 0.083061
# model saved to ./save/ckpt-3440
# batch 3441: loss 0.014398
# model saved to ./save/ckpt-3441
# batch 3442: loss 0.024279
# model saved to ./save/ckpt-3442
# batch 3443: loss 0.208441
# model saved to ./save/ckpt-3443
# batch 3444: loss 0.023474
# model saved to ./save/ckpt-3444
# batch 3445: loss 0.331909
# model saved to ./save/ckpt-3445
# batch 3446: loss 0.055667
# model saved to ./save/ckpt-3446
# batch 3447: loss 0.056022
# model saved to ./save/ckpt-3447
# batch 3448: loss 0.042345
# model saved to ./save/ckpt-3448
# batch 3449: loss 0.084910
# model saved to ./save/ckpt-3449
# batch 3450: loss 0.034580
# model saved to ./save/ckpt-3450
# batch 3451: loss 0.103962
# model saved to ./save/ckpt-3451
# batch 3452: loss 0.043831
# model saved to ./save/ckpt-3452
# batch 3453: loss 0.055246
# model saved to ./save/ckpt-3453
# batch 3454: loss 0.011595
# model saved to ./save/ckpt-3454
# batch 3455: loss 0.066674
# model saved to ./save/ckpt-3455
# batch 3456: loss 0.069393
# model saved to ./save/ckpt-3456
# batch 3457: loss 0.023460
# model saved to ./save/ckpt-3457
# batch 3458: loss 0.035182
# model saved to ./save/ckpt-3458
# batch 3459: loss 0.071805
# model saved to ./save/ckpt-3459
# batch 3460: loss 0.062763
# model saved to ./save/ckpt-3460
# batch 3461: loss 0.100975
# model saved to ./save/ckpt-3461
# batch 3462: loss 0.130477
# model saved to ./save/ckpt-3462
# batch 3463: loss 0.078943
# model saved to ./save/ckpt-3463
# batch 3464: loss 0.115580
# model saved to ./save/ckpt-3464
# batch 3465: loss 0.189896
# model saved to ./save/ckpt-3465
# batch 3466: loss 0.116473
# model saved to ./save/ckpt-3466
# batch 3467: loss 0.207134
# model saved to ./save/ckpt-3467
# batch 3468: loss 0.132670
# model saved to ./save/ckpt-3468
# batch 3469: loss 0.056723
# model saved to ./save/ckpt-3469
# batch 3470: loss 0.015575
# model saved to ./save/ckpt-3470
# batch 3471: loss 0.032958
# model saved to ./save/ckpt-3471
# batch 3472: loss 0.032848
# model saved to ./save/ckpt-3472
# batch 3473: loss 0.083334
# model saved to ./save/ckpt-3473
# batch 3474: loss 0.031384
# model saved to ./save/ckpt-3474
# batch 3475: loss 0.039264
# model saved to ./save/ckpt-3475
# batch 3476: loss 0.029661
# model saved to ./save/ckpt-3476
# batch 3477: loss 0.115076
# model saved to ./save/ckpt-3477
# batch 3478: loss 0.075360
# model saved to ./save/ckpt-3478
# batch 3479: loss 0.126546
# model saved to ./save/ckpt-3479
# batch 3480: loss 0.082324
# model saved to ./save/ckpt-3480
# batch 3481: loss 0.054419
# model saved to ./save/ckpt-3481
# batch 3482: loss 0.072060
# model saved to ./save/ckpt-3482
# batch 3483: loss 0.117385
# model saved to ./save/ckpt-3483
# batch 3484: loss 0.039908
# model saved to ./save/ckpt-3484
# batch 3485: loss 0.037075
# model saved to ./save/ckpt-3485
# batch 3486: loss 0.040427
# model saved to ./save/ckpt-3486
# batch 3487: loss 0.166236
# model saved to ./save/ckpt-3487
# batch 3488: loss 0.087159
# model saved to ./save/ckpt-3488
# batch 3489: loss 0.118408
# model saved to ./save/ckpt-3489
# batch 3490: loss 0.211658
# model saved to ./save/ckpt-3490
# batch 3491: loss 0.016463
# model saved to ./save/ckpt-3491
# batch 3492: loss 0.011040
# model saved to ./save/ckpt-3492
# batch 3493: loss 0.074681
# model saved to ./save/ckpt-3493
# batch 3494: loss 0.084326
# model saved to ./save/ckpt-3494
# batch 3495: loss 0.048049
# model saved to ./save/ckpt-3495
# batch 3496: loss 0.013710
# model saved to ./save/ckpt-3496
# batch 3497: loss 0.010543
# model saved to ./save/ckpt-3497
# batch 3498: loss 0.144964
# model saved to ./save/ckpt-3498
# batch 3499: loss 0.032693
# model saved to ./save/ckpt-3499
# batch 3500: loss 0.129761
# model saved to ./save/ckpt-3500
# batch 3501: loss 0.023196
# model saved to ./save/ckpt-3501
# batch 3502: loss 0.041508
# model saved to ./save/ckpt-3502
# batch 3503: loss 0.094667
# model saved to ./save/ckpt-3503
# batch 3504: loss 0.110182
# model saved to ./save/ckpt-3504
# batch 3505: loss 0.022386
# model saved to ./save/ckpt-3505
# batch 3506: loss 0.063270
# model saved to ./save/ckpt-3506
# batch 3507: loss 0.132386
# model saved to ./save/ckpt-3507
# batch 3508: loss 0.044506
# model saved to ./save/ckpt-3508
# batch 3509: loss 0.059390
# model saved to ./save/ckpt-3509
# batch 3510: loss 0.165648
# model saved to ./save/ckpt-3510
# batch 3511: loss 0.056851
# model saved to ./save/ckpt-3511
# batch 3512: loss 0.121273
# model saved to ./save/ckpt-3512
# batch 3513: loss 0.083880
# model saved to ./save/ckpt-3513
# batch 3514: loss 0.048230
# model saved to ./save/ckpt-3514
# batch 3515: loss 0.090674
# model saved to ./save/ckpt-3515
# batch 3516: loss 0.084139
# model saved to ./save/ckpt-3516
# batch 3517: loss 0.072056
# model saved to ./save/ckpt-3517
# batch 3518: loss 0.026167
# model saved to ./save/ckpt-3518
# batch 3519: loss 0.038190
# model saved to ./save/ckpt-3519
# batch 3520: loss 0.258814
# model saved to ./save/ckpt-3520
# batch 3521: loss 0.029870
# model saved to ./save/ckpt-3521
# batch 3522: loss 0.110434
# model saved to ./save/ckpt-3522
# batch 3523: loss 0.227645
# model saved to ./save/ckpt-3523
# batch 3524: loss 0.065868
# model saved to ./save/ckpt-3524
# batch 3525: loss 0.050934
# model saved to ./save/ckpt-3525
# batch 3526: loss 0.216584
# model saved to ./save/ckpt-3526
# batch 3527: loss 0.050171
# model saved to ./save/ckpt-3527
# batch 3528: loss 0.082294
# model saved to ./save/ckpt-3528
# batch 3529: loss 0.042307
# model saved to ./save/ckpt-3529
# batch 3530: loss 0.156231
# model saved to ./save/ckpt-3530
# batch 3531: loss 0.062568
# model saved to ./save/ckpt-3531
# batch 3532: loss 0.053965
# model saved to ./save/ckpt-3532
# batch 3533: loss 0.156562
# model saved to ./save/ckpt-3533
# batch 3534: loss 0.031795
# model saved to ./save/ckpt-3534
# batch 3535: loss 0.040151
# model saved to ./save/ckpt-3535
# batch 3536: loss 0.147778
# model saved to ./save/ckpt-3536
# batch 3537: loss 0.044323
# model saved to ./save/ckpt-3537
# batch 3538: loss 0.111488
# model saved to ./save/ckpt-3538
# batch 3539: loss 0.058763
# model saved to ./save/ckpt-3539
# batch 3540: loss 0.067396
# model saved to ./save/ckpt-3540
# batch 3541: loss 0.083770
# model saved to ./save/ckpt-3541
# batch 3542: loss 0.034896
# model saved to ./save/ckpt-3542
# batch 3543: loss 0.016905
# model saved to ./save/ckpt-3543
# batch 3544: loss 0.062529
# model saved to ./save/ckpt-3544
# batch 3545: loss 0.026899
# model saved to ./save/ckpt-3545
# batch 3546: loss 0.096127
# model saved to ./save/ckpt-3546
# batch 3547: loss 0.152996
# model saved to ./save/ckpt-3547
# batch 3548: loss 0.049821
# model saved to ./save/ckpt-3548
# batch 3549: loss 0.184988
# model saved to ./save/ckpt-3549
# batch 3550: loss 0.120366
# model saved to ./save/ckpt-3550
# batch 3551: loss 0.040176
# model saved to ./save/ckpt-3551
# batch 3552: loss 0.025042
# model saved to ./save/ckpt-3552
# batch 3553: loss 0.053259
# model saved to ./save/ckpt-3553
# batch 3554: loss 0.016943
# model saved to ./save/ckpt-3554
# batch 3555: loss 0.118503
# model saved to ./save/ckpt-3555
# batch 3556: loss 0.101190
# model saved to ./save/ckpt-3556
# batch 3557: loss 0.084810
# model saved to ./save/ckpt-3557
# batch 3558: loss 0.036687
# model saved to ./save/ckpt-3558
# batch 3559: loss 0.062170
# model saved to ./save/ckpt-3559
# batch 3560: loss 0.017456
# model saved to ./save/ckpt-3560
# batch 3561: loss 0.048207
# model saved to ./save/ckpt-3561
# batch 3562: loss 0.022520
# model saved to ./save/ckpt-3562
# batch 3563: loss 0.052562
# model saved to ./save/ckpt-3563
# batch 3564: loss 0.105614
# model saved to ./save/ckpt-3564
# batch 3565: loss 0.031338
# model saved to ./save/ckpt-3565
# batch 3566: loss 0.089042
# model saved to ./save/ckpt-3566
# batch 3567: loss 0.125696
# model saved to ./save/ckpt-3567
# batch 3568: loss 0.044131
# model saved to ./save/ckpt-3568
# batch 3569: loss 0.029453
# model saved to ./save/ckpt-3569
# batch 3570: loss 0.036101
# model saved to ./save/ckpt-3570
# batch 3571: loss 0.033355
# model saved to ./save/ckpt-3571
# batch 3572: loss 0.240073
# model saved to ./save/ckpt-3572
# batch 3573: loss 0.044496
# model saved to ./save/ckpt-3573
# batch 3574: loss 0.026040
# model saved to ./save/ckpt-3574
# batch 3575: loss 0.110719
# model saved to ./save/ckpt-3575
# batch 3576: loss 0.025658
# model saved to ./save/ckpt-3576
# batch 3577: loss 0.050724
# model saved to ./save/ckpt-3577
# batch 3578: loss 0.074975
# model saved to ./save/ckpt-3578
# batch 3579: loss 0.083046
# model saved to ./save/ckpt-3579
# batch 3580: loss 0.027866
# model saved to ./save/ckpt-3580
# batch 3581: loss 0.180741
# model saved to ./save/ckpt-3581
# batch 3582: loss 0.053199
# model saved to ./save/ckpt-3582
# batch 3583: loss 0.101882
# model saved to ./save/ckpt-3583
# batch 3584: loss 0.017629
# model saved to ./save/ckpt-3584
# batch 3585: loss 0.048405
# model saved to ./save/ckpt-3585
# batch 3586: loss 0.178145
# model saved to ./save/ckpt-3586
# batch 3587: loss 0.185987
# model saved to ./save/ckpt-3587
# batch 3588: loss 0.091915
# model saved to ./save/ckpt-3588
# batch 3589: loss 0.099537
# model saved to ./save/ckpt-3589
# batch 3590: loss 0.028277
# model saved to ./save/ckpt-3590
# batch 3591: loss 0.273113
# model saved to ./save/ckpt-3591
# batch 3592: loss 0.039550
# model saved to ./save/ckpt-3592
# batch 3593: loss 0.030326
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d54df7aefeb9> in <module>()
#      12         loss = tf.reduce_mean(loss)
#      13         print("batch %d: loss %f" % (batch_index, loss.numpy()))
# ---> 14     grads = tape.gradient(loss, model.variables)
#      15     optimizer.apply_gradients(grads_and_vars=zip(grads, model.variables))
#      16
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1071         output_gradients=output_gradients,
#    1072         sources_raw=flat_sources_raw,
# -> 1073         unconnected_gradients=unconnected_gradients)
#    1074
#    1075     if not self._persistent:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      75       output_gradients,
#      76       sources_raw,
# ---> 77       compat.as_str(unconnected_gradients.value))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     160       gradient_name_scope += forward_pass_name_scope + "/"
#     161     with ops.name_scope(gradient_name_scope):
# --> 162       return grad_fn(mock_op, *out_grads)
#     163   else:
#     164     return grad_fn(mock_op, *out_grads)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py in _MatMulGrad(op, grad)
#    1679         return _MatMulGradAgainstFirstOnly(op, grad)
#    1680       elif 0 in skip_input_indices:
# -> 1681         return _MatMulGradAgainstSecondOnly(op, grad)
#    1682   except AttributeError:
#    1683     # No gradient skipping, so do the full gradient computation
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py in _MatMulGradAgainstSecondOnly(op, grad)
#    1660   a = math_ops.conj(op.inputs[0])
#    1661   if not t_a and not t_b:
# -> 1662     grad_b = gen_math_ops.mat_mul(a, grad, transpose_a=True)
#    1663   elif not t_a and t_b:
#    1664     grad_b = gen_math_ops.mat_mul(grad, a, transpose_a=True)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    5619         _ctx._context_handle, tld.device_name, "MatMul", name,
#    5620         tld.op_callbacks, a, b, "transpose_a", transpose_a, "transpose_b",
# -> 5621         transpose_b)
#    5622       return _result
#    5623     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# # test.py 模型使用階段
#
# model = MyModel()
# checkpoint = tf.train.Checkpoint(myModel=model)             # 實例化Checkpoint，指定還原對象為model
# checkpoint.restore(tf.train.latest_checkpoint('./save'))    # 從文件還原模型參數
# # 模型使用程式碼

# %%
#恢復之前訓練的結果
model = MLP()
checkpoint = tf.train.Checkpoint(myAwesomeModel=model)  
checkpoint.restore(tf.train.latest_checkpoint('./save'))

sparse_categorical_accuracy = tf.keras.metrics.SparseCategoricalAccuracy()
num_batches = int(data_loader.num_test_data // batch_size)

for batch_index in range(num_batches):
    start_index, end_index = batch_index * batch_size, (batch_index + 1) * batch_size
    y_pred = model.predict(data_loader.test_data[start_index: end_index])
    sparse_categorical_accuracy.update_state(y_true=data_loader.test_label[start_index: end_index], y_pred=y_pred)
print("test accuracy: %f" % sparse_categorical_accuracy.result())
# Out:
# test accuracy: 0.970600
