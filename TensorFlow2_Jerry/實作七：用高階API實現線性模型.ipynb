# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
#sex:性別
#age:年齡
#n_siblings_spouses:船上的兄弟姊妹或配偶數
#parch:船上父母或子女數量
#fare:票價
#class:艙等
#deck:鄰近的甲板
#embark_town:登船的港口
#alone:是否單獨一人

# %%
train = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')
train
# Out:
#      survived     sex   age  ...     deck  embark_town  alone
# 0           0    male  22.0  ...  unknown  Southampton      n
# 1           1  female  38.0  ...        C    Cherbourg      n
# 2           1  female  26.0  ...  unknown  Southampton      y
# 3           1  female  35.0  ...        C  Southampton      n
# 4           0    male  28.0  ...  unknown   Queenstown      y
# ..        ...     ...   ...  ...      ...          ...    ...
# 622         0    male  28.0  ...  unknown  Southampton      y
# 623         0    male  25.0  ...  unknown  Southampton      y
# 624         1  female  19.0  ...        B  Southampton      y
# 625         0  female  28.0  ...  unknown  Southampton      n
# 626         0    male  32.0  ...  unknown   Queenstown      y
#
# [627 rows x 10 columns]

# %%
#讀取資料
train = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')
test = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv')
y_train = train.pop('survived')
y_test = test.pop('survived')
train
# Out:
#         sex   age  n_siblings_spouses  ...     deck  embark_town alone
# 0      male  22.0                   1  ...  unknown  Southampton     n
# 1    female  38.0                   1  ...        C    Cherbourg     n
# 2    female  26.0                   0  ...  unknown  Southampton     y
# 3    female  35.0                   1  ...        C  Southampton     n
# 4      male  28.0                   0  ...  unknown   Queenstown     y
# ..      ...   ...                 ...  ...      ...          ...   ...
# 622    male  28.0                   0  ...  unknown  Southampton     y
# 623    male  25.0                   0  ...  unknown  Southampton     y
# 624  female  19.0                   0  ...        B  Southampton     y
# 625  female  28.0                   1  ...  unknown  Southampton     n
# 626    male  32.0                   0  ...  unknown   Queenstown     y
#
# [627 rows x 9 columns]

# %%
categorical_columns = ['sex', 'n_siblings_spouses', 'parch', 'class', 'deck',
                       'embark_town', 'alone']
numeric_columns = ['age', 'fare']

feature_columns = []
#類別欄位處理
for feature_name in categorical_columns:
  #依據train的feature_name將categorical轉one-hot
  vocabulary = train[feature_name].unique()
  feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

#數值欄位處理
for feature_name in numeric_columns:
  feature_columns.append(tf.feature_column.numeric_column(feature_name,
                                                          dtype=tf.float32))

# %%
def make_input_fn(X, y, n_epochs=10, shuffle=True, batch_size=32):
  def input_function():
    dataset = tf.data.Dataset.from_tensor_slices((dict(X), y))
    if shuffle:
      dataset = dataset.shuffle(1000)
    dataset = dataset.batch(batch_size).repeat(n_epochs)
    return dataset
  return input_function

train_input_fn = make_input_fn(train, y_train)
test_input_fn = make_input_fn(test, y_test, n_epochs=1, shuffle=False)

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
linear_est.train(train_input_fn)
results = linear_est.evaluate(test_input_fn)
pd.Series(results).to_frame()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpnkl_nw6r
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpnkl_nw6r', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1727: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/ftrl.py:134: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpnkl_nw6r/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.6931472, step = 0
# INFO:tensorflow:global_step/sec: 103.086
# INFO:tensorflow:loss = 0.51453346, step = 100 (0.971 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 200...
# INFO:tensorflow:Saving checkpoints for 200 into /tmp/tmpnkl_nw6r/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 200...
# INFO:tensorflow:Loss for final step: 0.33429232.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-02-26T12:39:11Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpnkl_nw6r/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.61121s
# INFO:tensorflow:Finished evaluation at 2021-02-26-12:39:11
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.7689394, accuracy_baseline = 0.625, auc = 0.83021116, auc_precision_recall = 0.7916575, average_loss = 0.48579234, global_step = 200, label/mean = 0.375, loss = 0.4764858, precision = 0.7209302, prediction/mean = 0.34220275, recall = 0.6262626
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: /tmp/tmpnkl_nw6r/model.ckpt-200
#                                0
# accuracy                0.768939
# accuracy_baseline       0.625000
# auc                     0.830211
# auc_precision_recall    0.791658
# average_loss            0.485792
# label/mean              0.375000
# loss                    0.476486
# precision               0.720930
# prediction/mean         0.342203
# recall                  0.626263
# global_step           200.000000

# %%
pred_dicts = list(linear_est.predict(test_input_fn))
pred_dicts
# Out:
# INFO:tensorflow:Calling model_fn.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1727: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpnkl_nw6r/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.0727796], dtype=float32),
#   'logits': array([-2.5447557], dtype=float32),
#   'probabilities': array([0.92722046, 0.0727796 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22909726], dtype=float32),
#   'logits': array([-1.2134155], dtype=float32),
#   'probabilities': array([0.7709027 , 0.22909726], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67305666], dtype=float32),
#   'logits': array([0.7220425], dtype=float32),
#   'probabilities': array([0.32694337, 0.67305666], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5913165], dtype=float32),
#   'logits': array([0.36941037], dtype=float32),
#   'probabilities': array([0.4086835, 0.5913165], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24486144], dtype=float32),
#   'logits': array([-1.1262088], dtype=float32),
#   'probabilities': array([0.7551386 , 0.24486144], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7240467], dtype=float32),
#   'logits': array([0.9646242], dtype=float32),
#   'probabilities': array([0.2759533, 0.7240467], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5142684], dtype=float32),
#   'logits': array([0.05708917], dtype=float32),
#   'probabilities': array([0.4857316, 0.5142684], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10247867], dtype=float32),
#   'logits': array([-2.1699822], dtype=float32),
#   'probabilities': array([0.8975214 , 0.10247868], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57430613], dtype=float32),
#   'logits': array([0.29944214], dtype=float32),
#   'probabilities': array([0.42569384, 0.57430613], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.70231825], dtype=float32),
#   'logits': array([0.8583618], dtype=float32),
#   'probabilities': array([0.29768172, 0.70231825], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6497951], dtype=float32),
#   'logits': array([0.6181386], dtype=float32),
#   'probabilities': array([0.3502049, 0.6497951], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10260376], dtype=float32),
#   'logits': array([-2.168623], dtype=float32),
#   'probabilities': array([0.89739627, 0.10260376], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.81341386], dtype=float32),
#   'logits': array([1.4723469], dtype=float32),
#   'probabilities': array([0.18658616, 0.81341386], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32464048], dtype=float32),
#   'logits': array([-0.73252684], dtype=float32),
#   'probabilities': array([0.6753595 , 0.32464048], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82008654], dtype=float32),
#   'logits': array([1.5169339], dtype=float32),
#   'probabilities': array([0.17991346, 0.82008654], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43394023], dtype=float32),
#   'logits': array([-0.265793], dtype=float32),
#   'probabilities': array([0.5660598, 0.4339402], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14557469], dtype=float32),
#   'logits': array([-1.7697397], dtype=float32),
#   'probabilities': array([0.8544254, 0.1455747], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8047985], dtype=float32),
#   'logits': array([1.4165596], dtype=float32),
#   'probabilities': array([0.1952015, 0.8047985], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.335734], dtype=float32),
#   'logits': array([-0.68236357], dtype=float32),
#   'probabilities': array([0.66426605, 0.335734  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08439025], dtype=float32),
#   'logits': array([-2.3841383], dtype=float32),
#   'probabilities': array([0.9156098 , 0.08439025], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10506724], dtype=float32),
#   'logits': array([-2.142148], dtype=float32),
#   'probabilities': array([0.89493275, 0.10506724], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.0728587], dtype=float32),
#   'logits': array([-2.543584], dtype=float32),
#   'probabilities': array([0.92714137, 0.0728587 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6373505], dtype=float32),
#   'logits': array([0.563883], dtype=float32),
#   'probabilities': array([0.36264947, 0.6373505 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06759547], dtype=float32),
#   'logits': array([-2.6242259], dtype=float32),
#   'probabilities': array([0.9324046 , 0.06759547], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64822966], dtype=float32),
#   'logits': array([0.61126655], dtype=float32),
#   'probabilities': array([0.3517703 , 0.64822966], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51215464], dtype=float32),
#   'logits': array([0.04862794], dtype=float32),
#   'probabilities': array([0.4878454 , 0.51215464], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11372408], dtype=float32),
#   'logits': array([-2.0532532], dtype=float32),
#   'probabilities': array([0.88627595, 0.11372407], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16657934], dtype=float32),
#   'logits': array([-1.6100669], dtype=float32),
#   'probabilities': array([0.83342063, 0.16657932], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20141117], dtype=float32),
#   'logits': array([-1.3774977], dtype=float32),
#   'probabilities': array([0.79858875, 0.20141119], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7998995], dtype=float32),
#   'logits': array([1.3856666], dtype=float32),
#   'probabilities': array([0.20010047, 0.7998995 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12412821], dtype=float32),
#   'logits': array([-1.9539049], dtype=float32),
#   'probabilities': array([0.87587184, 0.1241282 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7395213], dtype=float32),
#   'logits': array([1.0434821], dtype=float32),
#   'probabilities': array([0.26047868, 0.7395213 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1761168], dtype=float32),
#   'logits': array([-1.5428814], dtype=float32),
#   'probabilities': array([0.8238832, 0.1761168], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6157213], dtype=float32),
#   'logits': array([0.47142646], dtype=float32),
#   'probabilities': array([0.38427866, 0.6157213 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20095408], dtype=float32),
#   'logits': array([-1.380342], dtype=float32),
#   'probabilities': array([0.7990459 , 0.20095408], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08873194], dtype=float32),
#   'logits': array([-2.3292172], dtype=float32),
#   'probabilities': array([0.91126806, 0.08873194], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13756596], dtype=float32),
#   'logits': array([-1.8356552], dtype=float32),
#   'probabilities': array([0.862434  , 0.13756596], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11941694], dtype=float32),
#   'logits': array([-1.9979632], dtype=float32),
#   'probabilities': array([0.8805831 , 0.11941694], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8176352], dtype=float32),
#   'logits': array([1.500407], dtype=float32),
#   'probabilities': array([0.18236482, 0.8176352 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08234468], dtype=float32),
#   'logits': array([-2.410908], dtype=float32),
#   'probabilities': array([0.9176553 , 0.08234467], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6840209], dtype=float32),
#   'logits': array([0.77231246], dtype=float32),
#   'probabilities': array([0.31597906, 0.6840209 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09514038], dtype=float32),
#   'logits': array([-2.2524264], dtype=float32),
#   'probabilities': array([0.90485966, 0.09514038], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3741419], dtype=float32),
#   'logits': array([-0.5144885], dtype=float32),
#   'probabilities': array([0.6258581, 0.3741419], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22110564], dtype=float32),
#   'logits': array([-1.2592349], dtype=float32),
#   'probabilities': array([0.77889436, 0.22110564], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1619748], dtype=float32),
#   'logits': array([-1.6436073], dtype=float32),
#   'probabilities': array([0.8380252, 0.1619748], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77054656], dtype=float32),
#   'logits': array([1.2113999], dtype=float32),
#   'probabilities': array([0.22945344, 0.77054656], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10254119], dtype=float32),
#   'logits': array([-2.1693027], dtype=float32),
#   'probabilities': array([0.89745885, 0.10254119], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25296158], dtype=float32),
#   'logits': array([-1.0828791], dtype=float32),
#   'probabilities': array([0.7470384 , 0.25296155], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30788472], dtype=float32),
#   'logits': array([-0.81002706], dtype=float32),
#   'probabilities': array([0.69211525, 0.30788472], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27392957], dtype=float32),
#   'logits': array([-0.97477597], dtype=float32),
#   'probabilities': array([0.7260704 , 0.27392957], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08739537], dtype=float32),
#   'logits': array([-2.3458605], dtype=float32),
#   'probabilities': array([0.91260463, 0.08739536], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20064561], dtype=float32),
#   'logits': array([-1.3822641], dtype=float32),
#   'probabilities': array([0.7993544 , 0.20064561], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05912272], dtype=float32),
#   'logits': array([-2.7671974], dtype=float32),
#   'probabilities': array([0.9408773 , 0.05912273], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09238327], dtype=float32),
#   'logits': array([-2.2848763], dtype=float32),
#   'probabilities': array([0.90761673, 0.09238327], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11010453], dtype=float32),
#   'logits': array([-2.0896738], dtype=float32),
#   'probabilities': array([0.8898955 , 0.11010454], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09579434], dtype=float32),
#   'logits': array([-2.2448533], dtype=float32),
#   'probabilities': array([0.9042057 , 0.09579434], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1575291], dtype=float32),
#   'logits': array([-1.676729], dtype=float32),
#   'probabilities': array([0.84247094, 0.1575291 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9076749], dtype=float32),
#   'logits': array([2.28557], dtype=float32),
#   'probabilities': array([0.09232513, 0.9076749 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16848251], dtype=float32),
#   'logits': array([-1.5964204], dtype=float32),
#   'probabilities': array([0.8315175 , 0.16848251], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08654808], dtype=float32),
#   'logits': array([-2.3565307], dtype=float32),
#   'probabilities': array([0.9134519 , 0.08654808], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14346085], dtype=float32),
#   'logits': array([-1.7868379], dtype=float32),
#   'probabilities': array([0.8565392 , 0.14346084], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49192753], dtype=float32),
#   'logits': array([-0.03229252], dtype=float32),
#   'probabilities': array([0.50807244, 0.49192756], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18205032], dtype=float32),
#   'logits': array([-1.5025176], dtype=float32),
#   'probabilities': array([0.81794965, 0.18205033], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7748667], dtype=float32),
#   'logits': array([1.2359986], dtype=float32),
#   'probabilities': array([0.22513326, 0.7748667 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16296028], dtype=float32),
#   'logits': array([-1.6363652], dtype=float32),
#   'probabilities': array([0.8370397 , 0.16296026], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6120946], dtype=float32),
#   'logits': array([0.45612535], dtype=float32),
#   'probabilities': array([0.3879054, 0.6120946], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2981137], dtype=float32),
#   'logits': array([-0.85629654], dtype=float32),
#   'probabilities': array([0.7018863 , 0.29811367], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08647571], dtype=float32),
#   'logits': array([-2.3574464], dtype=float32),
#   'probabilities': array([0.9135243 , 0.08647571], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10748175], dtype=float32),
#   'logits': array([-2.116726], dtype=float32),
#   'probabilities': array([0.8925183 , 0.10748175], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6245845], dtype=float32),
#   'logits': array([0.5090532], dtype=float32),
#   'probabilities': array([0.37541547, 0.6245845 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8361341], dtype=float32),
#   'logits': array([1.6297405], dtype=float32),
#   'probabilities': array([0.16386591, 0.8361341 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23506857], dtype=float32),
#   'logits': array([-1.179909], dtype=float32),
#   'probabilities': array([0.7649314 , 0.23506854], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.04294157], dtype=float32),
#   'logits': array([-3.1040242], dtype=float32),
#   'probabilities': array([0.9570585 , 0.04294157], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10750885], dtype=float32),
#   'logits': array([-2.1164434], dtype=float32),
#   'probabilities': array([0.8924911 , 0.10750885], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12367562], dtype=float32),
#   'logits': array([-1.9580741], dtype=float32),
#   'probabilities': array([0.87632436, 0.12367562], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08175082], dtype=float32),
#   'logits': array([-2.418793], dtype=float32),
#   'probabilities': array([0.91824913, 0.08175082], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10011805], dtype=float32),
#   'logits': array([-2.1959136], dtype=float32),
#   'probabilities': array([0.89988196, 0.10011805], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11941694], dtype=float32),
#   'logits': array([-1.9979632], dtype=float32),
#   'probabilities': array([0.8805831 , 0.11941694], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6854119], dtype=float32),
#   'logits': array([0.7787557], dtype=float32),
#   'probabilities': array([0.31458813, 0.6854119 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9218836], dtype=float32),
#   'logits': array([2.4682195], dtype=float32),
#   'probabilities': array([0.07811635, 0.9218836 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6170508], dtype=float32),
#   'logits': array([0.4770492], dtype=float32),
#   'probabilities': array([0.38294917, 0.6170508 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32464048], dtype=float32),
#   'logits': array([-0.73252684], dtype=float32),
#   'probabilities': array([0.6753595 , 0.32464048], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15499236], dtype=float32),
#   'logits': array([-1.6959698], dtype=float32),
#   'probabilities': array([0.84500766, 0.15499236], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7973442], dtype=float32),
#   'logits': array([1.3697772], dtype=float32),
#   'probabilities': array([0.20265584, 0.7973442 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07682382], dtype=float32),
#   'logits': array([-2.4863052], dtype=float32),
#   'probabilities': array([0.9231761 , 0.07682382], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20866321], dtype=float32),
#   'logits': array([-1.3330022], dtype=float32),
#   'probabilities': array([0.7913368, 0.2086632], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6056169], dtype=float32),
#   'logits': array([0.428925], dtype=float32),
#   'probabilities': array([0.39438304, 0.6056169 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08910313], dtype=float32),
#   'logits': array([-2.3246353], dtype=float32),
#   'probabilities': array([0.9108969 , 0.08910313], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7859497], dtype=float32),
#   'logits': array([1.3006821], dtype=float32),
#   'probabilities': array([0.21405023, 0.7859497 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8251941], dtype=float32),
#   'logits': array([1.5519426], dtype=float32),
#   'probabilities': array([0.17480586, 0.8251941 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.93480444], dtype=float32),
#   'logits': array([2.662946], dtype=float32),
#   'probabilities': array([0.06519556, 0.93480444], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1563511], dtype=float32),
#   'logits': array([-1.6856322], dtype=float32),
#   'probabilities': array([0.84364885, 0.1563511 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.0848107], dtype=float32),
#   'logits': array([-2.378709], dtype=float32),
#   'probabilities': array([0.9151893 , 0.08481071], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8758163], dtype=float32),
#   'logits': array([1.9533942], dtype=float32),
#   'probabilities': array([0.12418373, 0.8758163 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39050353], dtype=float32),
#   'logits': array([-0.44519606], dtype=float32),
#   'probabilities': array([0.6094964 , 0.39050353], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3234311], dtype=float32),
#   'logits': array([-0.73804814], dtype=float32),
#   'probabilities': array([0.6765689, 0.3234311], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16801664], dtype=float32),
#   'logits': array([-1.5997494], dtype=float32),
#   'probabilities': array([0.8319834 , 0.16801664], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06091234], dtype=float32),
#   'logits': array([-2.735473], dtype=float32),
#   'probabilities': array([0.9390876 , 0.06091235], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09709647], dtype=float32),
#   'logits': array([-2.2299106], dtype=float32),
#   'probabilities': array([0.90290356, 0.09709648], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22226584], dtype=float32),
#   'logits': array([-1.2525105], dtype=float32),
#   'probabilities': array([0.77773416, 0.22226584], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08267398], dtype=float32),
#   'logits': array([-2.406558], dtype=float32),
#   'probabilities': array([0.91732603, 0.08267397], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5280586], dtype=float32),
#   'logits': array([0.11235245], dtype=float32),
#   'probabilities': array([0.4719414, 0.5280586], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23890263], dtype=float32),
#   'logits': array([-1.1587052], dtype=float32),
#   'probabilities': array([0.7610974 , 0.23890263], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54758966], dtype=float32),
#   'logits': array([0.19093665], dtype=float32),
#   'probabilities': array([0.4524103 , 0.54758966], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6316469], dtype=float32),
#   'logits': array([0.53928846], dtype=float32),
#   'probabilities': array([0.3683531, 0.6316469], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17011888], dtype=float32),
#   'logits': array([-1.5847849], dtype=float32),
#   'probabilities': array([0.8298811, 0.1701189], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77832013], dtype=float32),
#   'logits': array([1.2559036], dtype=float32),
#   'probabilities': array([0.22167987, 0.77832013], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.76417774], dtype=float32),
#   'logits': array([1.175722], dtype=float32),
#   'probabilities': array([0.23582225, 0.76417774], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7097859], dtype=float32),
#   'logits': array([0.8943443], dtype=float32),
#   'probabilities': array([0.29021412, 0.7097859 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06628804], dtype=float32),
#   'logits': array([-2.6451585], dtype=float32),
#   'probabilities': array([0.93371195, 0.06628803], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.75220436], dtype=float32),
#   'logits': array([1.1104037], dtype=float32),
#   'probabilities': array([0.24779564, 0.75220436], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6421015], dtype=float32),
#   'logits': array([0.58449715], dtype=float32),
#   'probabilities': array([0.35789844, 0.6421015 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64225084], dtype=float32),
#   'logits': array([0.58514696], dtype=float32),
#   'probabilities': array([0.35774913, 0.64225084], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.04873306], dtype=float32),
#   'logits': array([-2.971437], dtype=float32),
#   'probabilities': array([0.951267  , 0.04873306], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7893291], dtype=float32),
#   'logits': array([1.3208861], dtype=float32),
#   'probabilities': array([0.21067092, 0.7893291 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.606538], dtype=float32),
#   'logits': array([0.43278286], dtype=float32),
#   'probabilities': array([0.393462, 0.606538], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08446379], dtype=float32),
#   'logits': array([-2.383187], dtype=float32),
#   'probabilities': array([0.9155362 , 0.08446379], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6155872], dtype=float32),
#   'logits': array([0.4708595], dtype=float32),
#   'probabilities': array([0.38441283, 0.6155872 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08682611], dtype=float32),
#   'logits': array([-2.353019], dtype=float32),
#   'probabilities': array([0.9131739 , 0.08682611], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74464476], dtype=float32),
#   'logits': array([1.0702516], dtype=float32),
#   'probabilities': array([0.25535524, 0.74464476], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48150933], dtype=float32),
#   'logits': array([-0.07399646], dtype=float32),
#   'probabilities': array([0.5184907, 0.4815093], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09594425], dtype=float32),
#   'logits': array([-2.2431238], dtype=float32),
#   'probabilities': array([0.9040558 , 0.09594425], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30124295], dtype=float32),
#   'logits': array([-0.8413861], dtype=float32),
#   'probabilities': array([0.69875705, 0.30124292], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8086976], dtype=float32),
#   'logits': array([1.4415696], dtype=float32),
#   'probabilities': array([0.1913024, 0.8086976], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.0839594], dtype=float32),
#   'logits': array([-2.3897274], dtype=float32),
#   'probabilities': array([0.9160406, 0.0839594], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08648182], dtype=float32),
#   'logits': array([-2.3573692], dtype=float32),
#   'probabilities': array([0.9135182 , 0.08648181], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63022107], dtype=float32),
#   'logits': array([0.53316516], dtype=float32),
#   'probabilities': array([0.36977896, 0.63022107], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10778662], dtype=float32),
#   'logits': array([-2.1135519], dtype=float32),
#   'probabilities': array([0.8922134 , 0.10778662], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10353214], dtype=float32),
#   'logits': array([-2.1585803], dtype=float32),
#   'probabilities': array([0.8964678 , 0.10353214], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17472549], dtype=float32),
#   'logits': array([-1.5524999], dtype=float32),
#   'probabilities': array([0.82527447, 0.17472549], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06733318], dtype=float32),
#   'logits': array([-2.6283948], dtype=float32),
#   'probabilities': array([0.93266684, 0.06733319], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6283672], dtype=float32),
#   'logits': array([0.5252184], dtype=float32),
#   'probabilities': array([0.37163278, 0.6283672 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10030193], dtype=float32),
#   'logits': array([-2.1938744], dtype=float32),
#   'probabilities': array([0.89969814, 0.10030192], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.04991175], dtype=float32),
#   'logits': array([-2.9462984], dtype=float32),
#   'probabilities': array([0.9500882 , 0.04991175], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08234468], dtype=float32),
#   'logits': array([-2.410908], dtype=float32),
#   'probabilities': array([0.9176553 , 0.08234467], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10287946], dtype=float32),
#   'logits': array([-2.1656322], dtype=float32),
#   'probabilities': array([0.89712054, 0.10287946], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1244642], dtype=float32),
#   'logits': array([-1.9508181], dtype=float32),
#   'probabilities': array([0.8755358 , 0.12446418], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13520008], dtype=float32),
#   'logits': array([-1.8557423], dtype=float32),
#   'probabilities': array([0.8648   , 0.1352001], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8479152], dtype=float32),
#   'logits': array([1.7183422], dtype=float32),
#   'probabilities': array([0.15208483, 0.8479152 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.0835008], dtype=float32),
#   'logits': array([-2.395705], dtype=float32),
#   'probabilities': array([0.9164992, 0.0835008], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09544363], dtype=float32),
#   'logits': array([-2.2489088], dtype=float32),
#   'probabilities': array([0.9045564 , 0.09544364], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64994454], dtype=float32),
#   'logits': array([0.61879545], dtype=float32),
#   'probabilities': array([0.35005546, 0.64994454], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
# ...
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34891877], dtype=float32),
#   'logits': array([-0.62379533], dtype=float32),
#   'probabilities': array([0.65108126, 0.34891877], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08039458], dtype=float32),
#   'logits': array([-2.436998], dtype=float32),
#   'probabilities': array([0.9196055 , 0.08039458], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12223781], dtype=float32),
#   'logits': array([-1.9714072], dtype=float32),
#   'probabilities': array([0.87776214, 0.12223782], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7417265], dtype=float32),
#   'logits': array([1.0549614], dtype=float32),
#   'probabilities': array([0.2582735, 0.7417265], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38318783], dtype=float32),
#   'logits': array([-0.4760392], dtype=float32),
#   'probabilities': array([0.61681217, 0.38318783], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1003032], dtype=float32),
#   'logits': array([-2.1938603], dtype=float32),
#   'probabilities': array([0.89969677, 0.10030319], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31676733], dtype=float32),
#   'logits': array([-0.7686678], dtype=float32),
#   'probabilities': array([0.68323267, 0.31676733], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2063059], dtype=float32),
#   'logits': array([-1.3473381], dtype=float32),
#   'probabilities': array([0.79369414, 0.20630589], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8248317], dtype=float32),
#   'logits': array([1.549432], dtype=float32),
#   'probabilities': array([0.17516832, 0.8248317 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7531185], dtype=float32),
#   'logits': array([1.1153139], dtype=float32),
#   'probabilities': array([0.24688153, 0.7531185 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11561374], dtype=float32),
#   'logits': array([-2.0346391], dtype=float32),
#   'probabilities': array([0.88438624, 0.11561374], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6344174], dtype=float32),
#   'logits': array([0.55121475], dtype=float32),
#   'probabilities': array([0.36558262, 0.6344174 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09464658], dtype=float32),
#   'logits': array([-2.2581756], dtype=float32),
#   'probabilities': array([0.90535337, 0.09464657], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13986522], dtype=float32),
#   'logits': array([-1.8164098], dtype=float32),
#   'probabilities': array([0.8601348 , 0.13986522], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58720124], dtype=float32),
#   'logits': array([0.35240743], dtype=float32),
#   'probabilities': array([0.41279873, 0.58720124], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10779317], dtype=float32),
#   'logits': array([-2.1134837], dtype=float32),
#   'probabilities': array([0.89220685, 0.10779317], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6387123], dtype=float32),
#   'logits': array([0.56977934], dtype=float32),
#   'probabilities': array([0.36128774, 0.6387123 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78864896], dtype=float32),
#   'logits': array([1.3168006], dtype=float32),
#   'probabilities': array([0.21135108, 0.78864896], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09340844], dtype=float32),
#   'logits': array([-2.2727103], dtype=float32),
#   'probabilities': array([0.90659153, 0.09340843], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65588963], dtype=float32),
#   'logits': array([0.6450302], dtype=float32),
#   'probabilities': array([0.34411034, 0.65588963], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09219798], dtype=float32),
#   'logits': array([-2.2870882], dtype=float32),
#   'probabilities': array([0.907802  , 0.09219797], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24633439], dtype=float32),
#   'logits': array([-1.118259], dtype=float32),
#   'probabilities': array([0.7536657 , 0.24633437], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08909348], dtype=float32),
#   'logits': array([-2.324754], dtype=float32),
#   'probabilities': array([0.9109065 , 0.08909348], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6555469], dtype=float32),
#   'logits': array([0.64351207], dtype=float32),
#   'probabilities': array([0.34445307, 0.6555469 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48539162], dtype=float32),
#   'logits': array([-0.05845014], dtype=float32),
#   'probabilities': array([0.5146084 , 0.48539162], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06007471], dtype=float32),
#   'logits': array([-2.7502115], dtype=float32),
#   'probabilities': array([0.9399253 , 0.06007471], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20005384], dtype=float32),
#   'logits': array([-1.3859578], dtype=float32),
#   'probabilities': array([0.7999461 , 0.20005384], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77325237], dtype=float32),
#   'logits': array([1.2267675], dtype=float32),
#   'probabilities': array([0.22674768, 0.77325237], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3035795], dtype=float32),
#   'logits': array([-0.8303101], dtype=float32),
#   'probabilities': array([0.6964205, 0.3035795], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.72932714], dtype=float32),
#   'logits': array([0.9912115], dtype=float32),
#   'probabilities': array([0.27067286, 0.72932714], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3108687], dtype=float32),
#   'logits': array([-0.79606116], dtype=float32),
#   'probabilities': array([0.6891313, 0.3108687], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06134809], dtype=float32),
#   'logits': array([-2.7278807], dtype=float32),
#   'probabilities': array([0.93865186, 0.06134809], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10503104], dtype=float32),
#   'logits': array([-2.142533], dtype=float32),
#   'probabilities': array([0.8949689 , 0.10503104], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1124222], dtype=float32),
#   'logits': array([-2.0662348], dtype=float32),
#   'probabilities': array([0.88757783, 0.1124222 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.02692851], dtype=float32),
#   'logits': array([-3.587272], dtype=float32),
#   'probabilities': array([0.9730715 , 0.02692851], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.81926185], dtype=float32),
#   'logits': array([1.5113543], dtype=float32),
#   'probabilities': array([0.18073815, 0.81926185], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6551917], dtype=float32),
#   'logits': array([0.6419391], dtype=float32),
#   'probabilities': array([0.34480834, 0.6551917 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13986246], dtype=float32),
#   'logits': array([-1.8164327], dtype=float32),
#   'probabilities': array([0.8601375 , 0.13986246], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19857803], dtype=float32),
#   'logits': array([-1.3952055], dtype=float32),
#   'probabilities': array([0.801422  , 0.19857801], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.831268], dtype=float32),
#   'logits': array([1.5946405], dtype=float32),
#   'probabilities': array([0.16873202, 0.831268  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2997933], dtype=float32),
#   'logits': array([-0.8482824], dtype=float32),
#   'probabilities': array([0.7002067, 0.2997933], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08586095], dtype=float32),
#   'logits': array([-2.3652537], dtype=float32),
#   'probabilities': array([0.91413903, 0.08586094], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7253401], dtype=float32),
#   'logits': array([0.97110724], dtype=float32),
#   'probabilities': array([0.27465984, 0.7253401 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7474372], dtype=float32),
#   'logits': array([1.0849903], dtype=float32),
#   'probabilities': array([0.25256282, 0.7474372 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07653546], dtype=float32),
#   'logits': array([-2.4903781], dtype=float32),
#   'probabilities': array([0.92346454, 0.07653547], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4566404], dtype=float32),
#   'logits': array([-0.17387512], dtype=float32),
#   'probabilities': array([0.54335964, 0.4566404 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16848251], dtype=float32),
#   'logits': array([-1.5964204], dtype=float32),
#   'probabilities': array([0.8315175 , 0.16848251], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34630752], dtype=float32),
#   'logits': array([-0.6353099], dtype=float32),
#   'probabilities': array([0.6536925, 0.3463075], dtype=float32)}]
