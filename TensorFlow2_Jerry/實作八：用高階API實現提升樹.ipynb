# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
#讀取資料
train = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')
test = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv')
y_train = train.pop('survived')
y_test = test.pop('survived')
train
# Out:
#         sex   age  n_siblings_spouses  ...     deck  embark_town alone
# 0      male  22.0                   1  ...  unknown  Southampton     n
# 1    female  38.0                   1  ...        C    Cherbourg     n
# 2    female  26.0                   0  ...  unknown  Southampton     y
# 3    female  35.0                   1  ...        C  Southampton     n
# 4      male  28.0                   0  ...  unknown   Queenstown     y
# ..      ...   ...                 ...  ...      ...          ...   ...
# 622    male  28.0                   0  ...  unknown  Southampton     y
# 623    male  25.0                   0  ...  unknown  Southampton     y
# 624  female  19.0                   0  ...        B  Southampton     y
# 625  female  28.0                   1  ...  unknown  Southampton     n
# 626    male  32.0                   0  ...  unknown   Queenstown     y
#
# [627 rows x 9 columns]

# %%
categorical_columns = ['sex', 'n_siblings_spouses', 'parch', 'class', 'deck',
                       'embark_town', 'alone']
numeric_columns = ['age', 'fare']

feature_columns = []
#類別欄位處理
for feature_name in categorical_columns:
  #依據train的feature_name將categorical轉one-hot
  vocabulary = train[feature_name].unique()
  feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

#數值欄位處理
for feature_name in numeric_columns:
  feature_columns.append(tf.feature_column.numeric_column(feature_name,
                                                          dtype=tf.float32))

# %%
def make_input_fn(X, y, n_epochs=10, shuffle=True, batch_size=64):
  def input_function():
    dataset = tf.data.Dataset.from_tensor_slices((dict(X), y))
    if shuffle:
      dataset = dataset.shuffle(1000)
    dataset = dataset.batch(batch_size).repeat(n_epochs)
    return dataset
  return input_function

train_input_fn = make_input_fn(train, y_train)
test_input_fn = make_input_fn(test, y_test, n_epochs=1, shuffle=False)

# %%
params = {
  'n_trees': 50, #樹的數量
  'max_depth': 3, #樹的深度
  'n_batches_per_layer': 5, #每一層訓練批次數
}

est = tf.estimator.BoostedTreesClassifier(feature_columns, **params)
est.train(train_input_fn, max_steps=100)

results = est.evaluate(test_input_fn)
pd.Series(results).to_frame()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpu6u25tqv
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpu6u25tqv', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpu6u25tqv/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.6931472, step = 0
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 95...
# INFO:tensorflow:Saving checkpoints for 95 into /tmp/tmpu6u25tqv/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 95...
# INFO:tensorflow:Loss for final step: 0.3901863.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_estimator/python/estimator/canned/head.py:642: auc (from tensorflow.python.ops.metrics_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# The value of AUC returned by this may race with the update so this is deprecated. Please use tf.keras.metrics.AUC instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-02-26T12:39:54Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu6u25tqv/model.ckpt-95
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.58184s
# INFO:tensorflow:Finished evaluation at 2021-02-26-12:39:55
# INFO:tensorflow:Saving dict for global step 95: accuracy = 0.77272725, accuracy_baseline = 0.625, auc = 0.8419957, auc_precision_recall = 0.80852854, average_loss = 0.46524405, global_step = 95, label/mean = 0.375, loss = 0.4493757, precision = 0.73493975, prediction/mean = 0.39867038, recall = 0.61616164
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 95: /tmp/tmpu6u25tqv/model.ckpt-95
#                               0
# accuracy               0.772727
# accuracy_baseline      0.625000
# auc                    0.841996
# auc_precision_recall   0.808529
# average_loss           0.465244
# label/mean             0.375000
# loss                   0.449376
# precision              0.734940
# prediction/mean        0.398670
# recall                 0.616162
# global_step           95.000000

# %%
pred_dicts = list(est.predict(test_input_fn))
pred_dicts
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu6u25tqv/model.ckpt-95
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34525838], dtype=float32),
#   'logits': array([-0.63994765], dtype=float32),
#   'probabilities': array([0.65474164, 0.34525838], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82922214], dtype=float32),
#   'logits': array([1.5801246], dtype=float32),
#   'probabilities': array([0.17077783, 0.82922214], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82490504], dtype=float32),
#   'logits': array([1.5499401], dtype=float32),
#   'probabilities': array([0.17509492, 0.82490504], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24805632], dtype=float32),
#   'logits': array([-1.1090055], dtype=float32),
#   'probabilities': array([0.75194365, 0.24805635], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6287357], dtype=float32),
#   'logits': array([0.52679694], dtype=float32),
#   'probabilities': array([0.37126425, 0.6287357 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17453575], dtype=float32),
#   'logits': array([-1.5538166], dtype=float32),
#   'probabilities': array([0.82546425, 0.17453572], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82462895], dtype=float32),
#   'logits': array([1.5480295], dtype=float32),
#   'probabilities': array([0.17537105, 0.82462895], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29654998], dtype=float32),
#   'logits': array([-0.8637812], dtype=float32),
#   'probabilities': array([0.70345   , 0.29654995], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8095775], dtype=float32),
#   'logits': array([1.4472673], dtype=float32),
#   'probabilities': array([0.19042248, 0.80957747], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4708634], dtype=float32),
#   'logits': array([-0.11667855], dtype=float32),
#   'probabilities': array([0.5291366, 0.4708634], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.80073935], dtype=float32),
#   'logits': array([1.3909217], dtype=float32),
#   'probabilities': array([0.19926065, 0.80073935], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49165052], dtype=float32),
#   'logits': array([-0.03340103], dtype=float32),
#   'probabilities': array([0.5083495 , 0.49165052], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17453575], dtype=float32),
#   'logits': array([-1.5538166], dtype=float32),
#   'probabilities': array([0.82546425, 0.17453572], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17453575], dtype=float32),
#   'logits': array([-1.5538166], dtype=float32),
#   'probabilities': array([0.82546425, 0.17453572], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4719736], dtype=float32),
#   'logits': array([-0.11222319], dtype=float32),
#   'probabilities': array([0.5280264 , 0.47197363], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2873084], dtype=float32),
#   'logits': array([-0.90849274], dtype=float32),
#   'probabilities': array([0.71269166, 0.2873084 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3918081], dtype=float32),
#   'logits': array([-0.4397183], dtype=float32),
#   'probabilities': array([0.6081919, 0.3918081], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6287357], dtype=float32),
#   'logits': array([0.52679694], dtype=float32),
#   'probabilities': array([0.37126425, 0.6287357 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17453575], dtype=float32),
#   'logits': array([-1.5538166], dtype=float32),
#   'probabilities': array([0.82546425, 0.17453572], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82490504], dtype=float32),
#   'logits': array([1.5499401], dtype=float32),
#   'probabilities': array([0.17509492, 0.82490504], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21844333], dtype=float32),
#   'logits': array([-1.274761], dtype=float32),
#   'probabilities': array([0.78155667, 0.21844335], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17453575], dtype=float32),
#   'logits': array([-1.5538166], dtype=float32),
#   'probabilities': array([0.82546425, 0.17453572], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24805632], dtype=float32),
#   'logits': array([-1.1090055], dtype=float32),
#   'probabilities': array([0.75194365, 0.24805635], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8504667], dtype=float32),
#   'logits': array([1.7382665], dtype=float32),
#   'probabilities': array([0.14953327, 0.8504668 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82490504], dtype=float32),
#   'logits': array([1.5499401], dtype=float32),
#   'probabilities': array([0.17509492, 0.82490504], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3368317], dtype=float32),
#   'logits': array([-0.6774455], dtype=float32),
#   'probabilities': array([0.6631683, 0.3368317], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36295366], dtype=float32),
#   'logits': array([-0.5625673], dtype=float32),
#   'probabilities': array([0.63704634, 0.36295363], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28015393], dtype=float32),
#   'logits': array([-0.9436982], dtype=float32),
#   'probabilities': array([0.71984607, 0.28015393], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28672004], dtype=float32),
#   'logits': array([-0.91136783], dtype=float32),
#   'probabilities': array([0.71328   , 0.28672004], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6287357], dtype=float32),
#   'logits': array([0.52679694], dtype=float32),
#   'probabilities': array([0.37126425, 0.6287357 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37560275], dtype=float32),
#   'logits': array([-0.50825477], dtype=float32),
#   'probabilities': array([0.6243973 , 0.37560275], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40229437], dtype=float32),
#   'logits': array([-0.39591438], dtype=float32),
#   'probabilities': array([0.59770566, 0.40229437], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34525838], dtype=float32),
#   'logits': array([-0.63994765], dtype=float32),
#   'probabilities': array([0.65474164, 0.34525838], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20510662], dtype=float32),
#   'logits': array([-1.354678], dtype=float32),
#   'probabilities': array([0.7948933, 0.2051066], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20510662], dtype=float32),
#   'logits': array([-1.354678], dtype=float32),
#   'probabilities': array([0.7948933, 0.2051066], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8574918], dtype=float32),
#   'logits': array([1.7946119], dtype=float32),
#   'probabilities': array([0.14250822, 0.8574918 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17453575], dtype=float32),
#   'logits': array([-1.5538166], dtype=float32),
#   'probabilities': array([0.82546425, 0.17453572], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3659637], dtype=float32),
#   'logits': array([-0.54957217], dtype=float32),
#   'probabilities': array([0.6340363 , 0.36596367], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4708634], dtype=float32),
#   'logits': array([-0.11667855], dtype=float32),
#   'probabilities': array([0.5291366, 0.4708634], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82462895], dtype=float32),
#   'logits': array([1.5480295], dtype=float32),
#   'probabilities': array([0.17537105, 0.82462895], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4301488], dtype=float32),
#   'logits': array([-0.2812441], dtype=float32),
#   'probabilities': array([0.5698512, 0.4301488], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31438994], dtype=float32),
#   'logits': array([-0.779675], dtype=float32),
#   'probabilities': array([0.68561006, 0.3143899 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49165052], dtype=float32),
#   'logits': array([-0.03340103], dtype=float32),
#   'probabilities': array([0.5083495 , 0.49165052], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8574918], dtype=float32),
#   'logits': array([1.7946119], dtype=float32),
#   'probabilities': array([0.14250822, 0.8574918 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3918081], dtype=float32),
#   'logits': array([-0.4397183], dtype=float32),
#   'probabilities': array([0.6081919, 0.3918081], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17453575], dtype=float32),
#   'logits': array([-1.5538166], dtype=float32),
#   'probabilities': array([0.82546425, 0.17453572], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8504667], dtype=float32),
#   'logits': array([1.7382665], dtype=float32),
#   'probabilities': array([0.14953327, 0.8504668 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29654998], dtype=float32),
#   'logits': array([-0.8637812], dtype=float32),
#   'probabilities': array([0.70345   , 0.29654995], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8384166], dtype=float32),
#   'logits': array([1.6464932], dtype=float32),
#   'probabilities': array([0.16158347, 0.8384165 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41699392], dtype=float32),
#   'logits': array([-0.33512595], dtype=float32),
#   'probabilities': array([0.5830061 , 0.41699392], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8095775], dtype=float32),
#   'logits': array([1.4472673], dtype=float32),
#   'probabilities': array([0.19042248, 0.80957747], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8095775], dtype=float32),
#   'logits': array([1.4472673], dtype=float32),
#   'probabilities': array([0.19042248, 0.80957747], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.86390626], dtype=float32),
#   'logits': array([1.8481203], dtype=float32),
#   'probabilities': array([0.13609375, 0.8639063 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37560275], dtype=float32),
#   'logits': array([-0.50825477], dtype=float32),
#   'probabilities': array([0.6243973 , 0.37560275], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8574918], dtype=float32),
#   'logits': array([1.7946119], dtype=float32),
#   'probabilities': array([0.14250822, 0.8574918 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40229437], dtype=float32),
#   'logits': array([-0.39591438], dtype=float32),
#   'probabilities': array([0.59770566, 0.40229437], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8384166], dtype=float32),
#   'logits': array([1.6464932], dtype=float32),
#   'probabilities': array([0.16158347, 0.8384165 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3957129], dtype=float32),
#   'logits': array([-0.42336047], dtype=float32),
#   'probabilities': array([0.6042871, 0.3957129], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34525838], dtype=float32),
#   'logits': array([-0.63994765], dtype=float32),
#   'probabilities': array([0.65474164, 0.34525838], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44703317], dtype=float32),
#   'logits': array([-0.21266526], dtype=float32),
#   'probabilities': array([0.55296683, 0.44703317], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3995701], dtype=float32),
#   'logits': array([-0.40725666], dtype=float32),
#   'probabilities': array([0.6004299 , 0.39957008], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6287357], dtype=float32),
#   'logits': array([0.52679694], dtype=float32),
#   'probabilities': array([0.37126425, 0.6287357 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8432375], dtype=float32),
#   'logits': array([1.6825167], dtype=float32),
#   'probabilities': array([0.15676251, 0.8432375 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8095775], dtype=float32),
#   'logits': array([1.4472673], dtype=float32),
#   'probabilities': array([0.19042248, 0.80957747], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8095775], dtype=float32),
#   'logits': array([1.4472673], dtype=float32),
#   'probabilities': array([0.19042248, 0.80957747], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8574918], dtype=float32),
#   'logits': array([1.7946119], dtype=float32),
#   'probabilities': array([0.14250822, 0.8574918 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5302846], dtype=float32),
#   'logits': array([0.12128673], dtype=float32),
#   'probabilities': array([0.46971545, 0.5302846 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17453575], dtype=float32),
#   'logits': array([-1.5538166], dtype=float32),
#   'probabilities': array([0.82546425, 0.17453572], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6287357], dtype=float32),
#   'logits': array([0.52679694], dtype=float32),
#   'probabilities': array([0.37126425, 0.6287357 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82490504], dtype=float32),
#   'logits': array([1.5499401], dtype=float32),
#   'probabilities': array([0.17509492, 0.82490504], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4708634], dtype=float32),
#   'logits': array([-0.11667855], dtype=float32),
#   'probabilities': array([0.5291366, 0.4708634], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49823862], dtype=float32),
#   'logits': array([-0.00704559], dtype=float32),
#   'probabilities': array([0.5017614, 0.4982386], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8324998], dtype=float32),
#   'logits': array([1.6034485], dtype=float32),
#   'probabilities': array([0.1675002 , 0.83249986], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8095775], dtype=float32),
#   'logits': array([1.4472673], dtype=float32),
#   'probabilities': array([0.19042248, 0.80957747], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37560275], dtype=float32),
#   'logits': array([-0.50825477], dtype=float32),
#   'probabilities': array([0.6243973 , 0.37560275], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8574918], dtype=float32),
#   'logits': array([1.7946119], dtype=float32),
#   'probabilities': array([0.14250822, 0.8574918 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17453575], dtype=float32),
#   'logits': array([-1.5538166], dtype=float32),
#   'probabilities': array([0.82546425, 0.17453572], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8504667], dtype=float32),
#   'logits': array([1.7382665], dtype=float32),
#   'probabilities': array([0.14953327, 0.8504668 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
# ...
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37560275], dtype=float32),
#   'logits': array([-0.50825477], dtype=float32),
#   'probabilities': array([0.6243973 , 0.37560275], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20510662], dtype=float32),
#   'logits': array([-1.354678], dtype=float32),
#   'probabilities': array([0.7948933, 0.2051066], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8095775], dtype=float32),
#   'logits': array([1.4472673], dtype=float32),
#   'probabilities': array([0.19042248, 0.80957747], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44703317], dtype=float32),
#   'logits': array([-0.21266526], dtype=float32),
#   'probabilities': array([0.55296683, 0.44703317], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3205074], dtype=float32),
#   'logits': array([-0.7514408], dtype=float32),
#   'probabilities': array([0.67949253, 0.32050744], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8574918], dtype=float32),
#   'logits': array([1.7946119], dtype=float32),
#   'probabilities': array([0.14250822, 0.8574918 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8574918], dtype=float32),
#   'logits': array([1.7946119], dtype=float32),
#   'probabilities': array([0.14250822, 0.8574918 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49165052], dtype=float32),
#   'logits': array([-0.03340103], dtype=float32),
#   'probabilities': array([0.5083495 , 0.49165052], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82490504], dtype=float32),
#   'logits': array([1.5499401], dtype=float32),
#   'probabilities': array([0.17509492, 0.82490504], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.859687], dtype=float32),
#   'logits': array([1.8126925], dtype=float32),
#   'probabilities': array([0.14031303, 0.859687  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36179274], dtype=float32),
#   'logits': array([-0.5675916], dtype=float32),
#   'probabilities': array([0.63820726, 0.36179274], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3205074], dtype=float32),
#   'logits': array([-0.7514408], dtype=float32),
#   'probabilities': array([0.67949253, 0.32050744], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6027515], dtype=float32),
#   'logits': array([0.41694307], dtype=float32),
#   'probabilities': array([0.39724848, 0.6027515 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4719736], dtype=float32),
#   'logits': array([-0.11222319], dtype=float32),
#   'probabilities': array([0.5280264 , 0.47197363], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25500458], dtype=float32),
#   'logits': array([-1.0720966], dtype=float32),
#   'probabilities': array([0.7449954 , 0.25500458], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6287357], dtype=float32),
#   'logits': array([0.52679694], dtype=float32),
#   'probabilities': array([0.37126425, 0.6287357 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29706892], dtype=float32),
#   'logits': array([-0.8612947], dtype=float32),
#   'probabilities': array([0.7029311 , 0.29706892], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8039388], dtype=float32),
#   'logits': array([1.4110965], dtype=float32),
#   'probabilities': array([0.19606118, 0.8039388 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3205074], dtype=float32),
#   'logits': array([-0.7514408], dtype=float32),
#   'probabilities': array([0.67949253, 0.32050744], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2873084], dtype=float32),
#   'logits': array([-0.90849274], dtype=float32),
#   'probabilities': array([0.71269166, 0.2873084 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6287357], dtype=float32),
#   'logits': array([0.52679694], dtype=float32),
#   'probabilities': array([0.37126425, 0.6287357 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82490504], dtype=float32),
#   'logits': array([1.5499401], dtype=float32),
#   'probabilities': array([0.17509492, 0.82490504], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16897202], dtype=float32),
#   'logits': array([-1.5929303], dtype=float32),
#   'probabilities': array([0.8310279 , 0.16897202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8213748], dtype=float32),
#   'logits': array([1.5256897], dtype=float32),
#   'probabilities': array([0.1786252, 0.8213748], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4708634], dtype=float32),
#   'logits': array([-0.11667855], dtype=float32),
#   'probabilities': array([0.5291366, 0.4708634], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.87039614], dtype=float32),
#   'logits': array([1.9044658], dtype=float32),
#   'probabilities': array([0.12960386, 0.87039614], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8324998], dtype=float32),
#   'logits': array([1.6034485], dtype=float32),
#   'probabilities': array([0.1675002 , 0.83249986], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17453575], dtype=float32),
#   'logits': array([-1.5538166], dtype=float32),
#   'probabilities': array([0.82546425, 0.17453572], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36295366], dtype=float32),
#   'logits': array([-0.5625673], dtype=float32),
#   'probabilities': array([0.63704634, 0.36295363], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18777516], dtype=float32),
#   'logits': array([-1.4645319], dtype=float32),
#   'probabilities': array([0.81222486, 0.18777516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37560275], dtype=float32),
#   'logits': array([-0.50825477], dtype=float32),
#   'probabilities': array([0.6243973 , 0.37560275], dtype=float32)}]
